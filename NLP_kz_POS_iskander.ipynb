# %% [markdown]
# # **Kazakh POS tagger**

# %%
import nltk
import pprint
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_extraction import DictVectorizer
from sklearn.pipeline import Pipeline
from joblib import dump

# %%
# Parse the Kazakh Dependency Treebank in CoNLL-U format
def parse_conllu(file_path):
    sentences = []
    current_sentence = []

    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            if line.strip() == '':  # New sentence
                if current_sentence:
                    sentences.append(current_sentence)
                    current_sentence = []
            else:
                # CoNLL-U format (columns: ID, FORM, LEMMA, UPOS, XPOS, etc.)
                parts = line.strip().split('\t')
                if len(parts) > 4:
                    word, pos_tag = parts[1], parts[3]  # FORM and UPOS
                    current_sentence.append((word, pos_tag))

    return sentences

# %%
def features(sentence, index):
    """ sentence: [w1, w2, ...], index: the index of the word """
    return {
        'word': sentence[index],
        'is_first': index == 0,
        'is_last': index == len(sentence) - 1,
        'is_capitalized': sentence[index][0].upper() == sentence[index][0],
        'is_all_caps': sentence[index].upper() == sentence[index],
        'is_all_lower': sentence[index].lower() == sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:3],
        'prefix-3': sentence[index][:4],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-3:],
        'suffix-3': sentence[index][-4:],
        'prev_word': '' if index == 0 else sentence[index - 1],
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1],
        'has_hyphen': '-' in sentence[index],
        'is_numeric': sentence[index].isdigit(),
        'capitals_inside': sentence[index][1:].lower() != sentence[index][1:]
    }

# %%
def untag(tagged_sentence):
    return [w for w, t in tagged_sentence]

# %%
def transform_to_dataset(tagged_sentences):
    X, y = [], []

    for tagged in tagged_sentences:
        for index in range(len(tagged)):
            X.append(features(untag(tagged), index))
            y.append(tagged[index][1])

    return X, y

# %%
kazakh_sentences = parse_conllu('kdt-NLANU-0.01.connlu.txt')

# %%
print(kazakh_sentences[0])
# Out:
# [('ҚТЖ', 'PROPN'), ('халықаралық', 'ADJ'), ('серіктестікті', 'NOUN'), ('кеңейтуде', 'VERB')]

# %%
cutoff = int(.75 * len(kazakh_sentences))
training_sentences = kazakh_sentences[:cutoff]
test_sentences = kazakh_sentences[cutoff:]

# %%
X_train, y_train = transform_to_dataset(training_sentences)
X_test, y_test = transform_to_dataset(test_sentences)

# %%
X_train
# Out:
# [{'word': 'ҚТЖ',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'ҚТЖ',
#   'prefix-3': 'ҚТЖ',
#   'suffix-1': 'Ж',
#   'suffix-2': 'ҚТЖ',
#   'suffix-3': 'ҚТЖ',
#   'prev_word': '',
#   'next_word': 'халықаралық',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': True},
#  {'word': 'халықаралық',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'х',
#   'prefix-2': 'хал',
#   'prefix-3': 'халы',
#   'suffix-1': 'қ',
#   'suffix-2': 'лық',
#   'suffix-3': 'алық',
#   'prev_word': 'ҚТЖ',
#   'next_word': 'серіктестікті',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'серіктестікті',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'с',
#   'prefix-2': 'сер',
#   'prefix-3': 'сері',
#   'suffix-1': 'і',
#   'suffix-2': 'кті',
#   'suffix-3': 'ікті',
#   'prev_word': 'халықаралық',
#   'next_word': 'кеңейтуде',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'кеңейтуде',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'кең',
#   'prefix-3': 'кеңе',
#   'suffix-1': 'е',
#   'suffix-2': 'уде',
#   'suffix-3': 'туде',
#   'prev_word': 'серіктестікті',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '160',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '1',
#   'prefix-2': '160',
#   'prefix-3': '160',
#   'suffix-1': '0',
#   'suffix-2': '160',
#   'suffix-3': '160',
#   'prev_word': '',
#   'next_word': 'мың',
#   'has_hyphen': False,
#   'is_numeric': True,
#   'capitals_inside': False},
#  {'word': 'мың',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'м',
#   'prefix-2': 'мың',
#   'prefix-3': 'мың',
#   'suffix-1': 'ң',
#   'suffix-2': 'мың',
#   'suffix-3': 'мың',
#   'prev_word': '160',
#   'next_word': 'босқынға',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'босқынға',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бос',
#   'prefix-3': 'босқ',
#   'suffix-1': 'а',
#   'suffix-2': 'нға',
#   'suffix-3': 'ынға',
#   'prev_word': 'мың',
#   'next_word': 'есік',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'есік',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'е',
#   'prefix-2': 'есі',
#   'prefix-3': 'есік',
#   'suffix-1': 'к',
#   'suffix-2': 'сік',
#   'suffix-3': 'есік',
#   'prev_word': 'босқынға',
#   'next_word': 'ашылды',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ашылды',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ашы',
#   'prefix-3': 'ашыл',
#   'suffix-1': 'ы',
#   'suffix-2': 'лды',
#   'suffix-3': 'ылды',
#   'prev_word': 'есік',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Қазақ',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'Қаз',
#   'prefix-3': 'Қаза',
#   'suffix-1': 'қ',
#   'suffix-2': 'зақ',
#   'suffix-3': 'азақ',
#   'prev_word': '',
#   'next_word': 'халқының',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'халқының',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'х',
#   'prefix-2': 'хал',
#   'prefix-3': 'халқ',
#   'suffix-1': 'ң',
#   'suffix-2': 'ның',
#   'suffix-3': 'ының',
#   'prev_word': 'Қазақ',
#   'next_word': 'басты',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'басты',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бас',
#   'prefix-3': 'баст',
#   'suffix-1': 'ы',
#   'suffix-2': 'сты',
#   'suffix-3': 'асты',
#   'prev_word': 'халқының',
#   'next_word': 'жетістіктерінің',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жетістіктерінің',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жет',
#   'prefix-3': 'жеті',
#   'suffix-1': 'ң',
#   'suffix-2': 'нің',
#   'suffix-3': 'інің',
#   'prev_word': 'басты',
#   'next_word': 'бірі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бірі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бір',
#   'prefix-3': 'бірі',
#   'suffix-1': 'і',
#   'suffix-2': 'ірі',
#   'suffix-3': 'бірі',
#   'prev_word': 'жетістіктерінің',
#   'next_word': 'бай',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бай',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бай',
#   'prefix-3': 'бай',
#   'suffix-1': 'й',
#   'suffix-2': 'бай',
#   'suffix-3': 'бай',
#   'prev_word': 'бірі',
#   'next_word': 'мәдени',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'мәдени',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'м',
#   'prefix-2': 'мәд',
#   'prefix-3': 'мәде',
#   'suffix-1': 'и',
#   'suffix-2': 'ени',
#   'suffix-3': 'дени',
#   'prev_word': 'бай',
#   'next_word': 'мұра',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'мұра',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'м',
#   'prefix-2': 'мұр',
#   'prefix-3': 'мұра',
#   'suffix-1': 'а',
#   'suffix-2': 'ұра',
#   'suffix-3': 'мұра',
#   'prev_word': 'мәдени',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'мұра',
#   'next_word': 'тарих',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'тарих',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тар',
#   'prefix-3': 'тари',
#   'suffix-1': 'х',
#   'suffix-2': 'рих',
#   'suffix-3': 'арих',
#   'prev_word': ',',
#   'next_word': 'пен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'пен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'п',
#   'prefix-2': 'пен',
#   'prefix-3': 'пен',
#   'suffix-1': 'н',
#   'suffix-2': 'пен',
#   'suffix-3': 'пен',
#   'prev_word': 'тарих',
#   'next_word': 'ұрпақтан',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ұрпақтан',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ұ',
#   'prefix-2': 'ұрп',
#   'prefix-3': 'ұрпа',
#   'suffix-1': 'н',
#   'suffix-2': 'тан',
#   'suffix-3': 'қтан',
#   'prev_word': 'пен',
#   'next_word': 'ұрпаққа',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ұрпаққа',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ұ',
#   'prefix-2': 'ұрп',
#   'prefix-3': 'ұрпа',
#   'suffix-1': 'а',
#   'suffix-2': 'ққа',
#   'suffix-3': 'аққа',
#   'prev_word': 'ұрпақтан',
#   'next_word': 'жалғасын',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жалғасын',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жал',
#   'prefix-3': 'жалғ',
#   'suffix-1': 'н',
#   'suffix-2': 'сын',
#   'suffix-3': 'асын',
#   'prev_word': 'ұрпаққа',
#   'next_word': 'тауып',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'тауып',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тау',
#   'prefix-3': 'тауы',
#   'suffix-1': 'п',
#   'suffix-2': 'уып',
#   'suffix-3': 'ауып',
#   'prev_word': 'жалғасын',
#   'next_word': 'келе',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'келе',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'кел',
#   'prefix-3': 'келе',
#   'suffix-1': 'е',
#   'suffix-2': 'еле',
#   'suffix-3': 'келе',
#   'prev_word': 'тауып',
#   'next_word': 'жатқан',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жатқан',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жат',
#   'prefix-3': 'жатқ',
#   'suffix-1': 'н',
#   'suffix-2': 'қан',
#   'suffix-3': 'тқан',
#   'prev_word': 'келе',
#   'next_word': 'салт-дәстүрлер',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'салт-дәстүрлер',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'с',
#   'prefix-2': 'сал',
#   'prefix-3': 'салт',
#   'suffix-1': 'р',
#   'suffix-2': 'лер',
#   'suffix-3': 'рлер',
#   'prev_word': 'жатқан',
#   'next_word': 'болып',
#   'has_hyphen': True,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'болып',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бол',
#   'prefix-3': 'болы',
#   'suffix-1': 'п',
#   'suffix-2': 'лып',
#   'suffix-3': 'олып',
#   'prev_word': 'салт-дәстүрлер',
#   'next_word': 'табылады',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'табылады',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'таб',
#   'prefix-3': 'табы',
#   'suffix-1': 'ы',
#   'suffix-2': 'ады',
#   'suffix-3': 'лады',
#   'prev_word': 'болып',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'табылады',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Нұржанның',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Н',
#   'prefix-2': 'Нұр',
#   'prefix-3': 'Нұрж',
#   'suffix-1': 'ң',
#   'suffix-2': 'ның',
#   'suffix-3': 'нның',
#   'prev_word': '',
#   'next_word': 'үйленгеніне',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'үйленгеніне',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ү',
#   'prefix-2': 'үйл',
#   'prefix-3': 'үйле',
#   'suffix-1': 'е',
#   'suffix-2': 'іне',
#   'suffix-3': 'ніне',
#   'prev_word': 'Нұржанның',
#   'next_word': 'бес',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бес',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бес',
#   'prefix-3': 'бес',
#   'suffix-1': 'с',
#   'suffix-2': 'бес',
#   'suffix-3': 'бес',
#   'prev_word': 'үйленгеніне',
#   'next_word': 'жыл',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жыл',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жыл',
#   'prefix-3': 'жыл',
#   'suffix-1': 'л',
#   'suffix-2': 'жыл',
#   'suffix-3': 'жыл',
#   'prev_word': 'бес',
#   'next_word': 'болып',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'болып',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бол',
#   'prefix-3': 'болы',
#   'suffix-1': 'п',
#   'suffix-2': 'лып',
#   'suffix-3': 'олып',
#   'prev_word': 'жыл',
#   'next_word': 'еді',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'еді',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'е',
#   'prefix-2': 'еді',
#   'prefix-3': 'еді',
#   'suffix-1': 'і',
#   'suffix-2': 'еді',
#   'suffix-3': 'еді',
#   'prev_word': 'болып',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'еді',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Ол',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'О',
#   'prefix-2': 'Ол',
#   'prefix-3': 'Ол',
#   'suffix-1': 'л',
#   'suffix-2': 'Ол',
#   'suffix-3': 'Ол',
#   'prev_word': '',
#   'next_word': 'қоралар',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қоралар',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қор',
#   'prefix-3': 'қора',
#   'suffix-1': 'р',
#   'suffix-2': 'лар',
#   'suffix-3': 'алар',
#   'prev_word': 'Ол',
#   'next_word': 'өзімен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'өзімен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ө',
#   'prefix-2': 'өзі',
#   'prefix-3': 'өзім',
#   'suffix-1': 'н',
#   'suffix-2': 'мен',
#   'suffix-3': 'імен',
#   'prev_word': 'қоралар',
#   'next_word': 'немере',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'немере',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'н',
#   'prefix-2': 'нем',
#   'prefix-3': 'неме',
#   'suffix-1': 'е',
#   'suffix-2': 'ере',
#   'suffix-3': 'мере',
#   'prev_word': 'өзімен',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'немере',
#   'next_word': 'шөберелес',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'шөберелес',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ш',
#   'prefix-2': 'шөб',
#   'prefix-3': 'шөбе',
#   'suffix-1': 'с',
#   'suffix-2': 'лес',
#   'suffix-3': 'елес',
#   'prev_word': ',',
#   'next_word': 'ағайындарынікі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ағайындарынікі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'аға',
#   'prefix-3': 'ағай',
#   'suffix-1': 'і',
#   'suffix-2': 'ікі',
#   'suffix-3': 'нікі',
#   'prev_word': 'шөберелес',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'ағайындарынікі',
#   'next_word': 'осы',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'осы',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'о',
#   'prefix-2': 'осы',
#   'prefix-3': 'осы',
#   'suffix-1': 'ы',
#   'suffix-2': 'осы',
#   'suffix-3': 'осы',
#   'prev_word': ',',
#   'next_word': 'ауылдың',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ауылдың',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ауы',
#   'prefix-3': 'ауыл',
#   'suffix-1': 'ң',
#   'suffix-2': 'дың',
#   'suffix-3': 'лдың',
#   'prev_word': 'осы',
#   'next_word': 'бас',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бас',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бас',
#   'prefix-3': 'бас',
#   'suffix-1': 'с',
#   'suffix-2': 'бас',
#   'suffix-3': 'бас',
#   'prev_word': 'ауылдың',
#   'next_word': 'көтерері',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'көтерері',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'көт',
#   'prefix-3': 'көте',
#   'suffix-1': 'і',
#   'suffix-2': 'ері',
#   'suffix-3': 'рері',
#   'prev_word': 'бас',
#   'next_word': '—',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '—',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '—',
#   'prefix-2': '—',
#   'prefix-3': '—',
#   'suffix-1': '—',
#   'suffix-2': '—',
#   'suffix-3': '—',
#   'prev_word': 'көтерері',
#   'next_word': 'Мұқаш',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Мұқаш',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'М',
#   'prefix-2': 'Мұқ',
#   'prefix-3': 'Мұқа',
#   'suffix-1': 'ш',
#   'suffix-2': 'қаш',
#   'suffix-3': 'ұқаш',
#   'prev_word': '—',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'Мұқаш',
#   'next_word': 'ақсақалы',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ақсақалы',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ақс',
#   'prefix-3': 'ақса',
#   'suffix-1': 'ы',
#   'suffix-2': 'алы',
#   'suffix-3': 'қалы',
#   'prev_word': ',',
#   'next_word': '—',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '—',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '—',
#   'prefix-2': '—',
#   'prefix-3': '—',
#   'suffix-1': '—',
#   'suffix-2': '—',
#   'suffix-3': '—',
#   'prev_word': 'ақсақалы',
#   'next_word': 'Тезекбай',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Тезекбай',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Т',
#   'prefix-2': 'Тез',
#   'prefix-3': 'Тезе',
#   'suffix-1': 'й',
#   'suffix-2': 'бай',
#   'suffix-3': 'кбай',
#   'prev_word': '—',
#   'next_word': 'молда',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'молда',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'м',
#   'prefix-2': 'мол',
#   'prefix-3': 'молд',
#   'suffix-1': 'а',
#   'suffix-2': 'лда',
#   'suffix-3': 'олда',
#   'prev_word': 'Тезекбай',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'молда',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Қартқожа',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'Қар',
#   'prefix-3': 'Қарт',
#   'suffix-1': 'а',
#   'suffix-2': 'ожа',
#   'suffix-3': 'қожа',
#   'prev_word': '',
#   'next_word': 'сампылдап',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'сампылдап',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'с',
#   'prefix-2': 'сам',
#   'prefix-3': 'самп',
#   'suffix-1': 'п',
#   'suffix-2': 'дап',
#   'suffix-3': 'лдап',
#   'prev_word': 'Қартқожа',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'сампылдап',
#   'next_word': 'ауылнай',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ауылнай',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ауы',
#   'prefix-3': 'ауыл',
#   'suffix-1': 'й',
#   'suffix-2': 'най',
#   'suffix-3': 'лнай',
#   'prev_word': ',',
#   'next_word': 'ішіндегі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ішіндегі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'і',
#   'prefix-2': 'іші',
#   'prefix-3': 'ішін',
#   'suffix-1': 'і',
#   'suffix-2': 'егі',
#   'suffix-3': 'дегі',
#   'prev_word': 'ауылнай',
#   'next_word': '«',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '«',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '«',
#   'prefix-2': '«',
#   'prefix-3': '«',
#   'suffix-1': '«',
#   'suffix-2': '«',
#   'suffix-3': '«',
#   'prev_word': 'ішіндегі',
#   'next_word': 'адам',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'адам',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ада',
#   'prefix-3': 'адам',
#   'suffix-1': 'м',
#   'suffix-2': 'дам',
#   'suffix-3': 'адам',
#   'prev_word': '«',
#   'next_word': '»',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '»',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '»',
#   'prefix-2': '»',
#   'prefix-3': '»',
#   'suffix-1': '»',
#   'suffix-2': '»',
#   'suffix-3': '»',
#   'prev_word': 'адам',
#   'next_word': '–',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '–',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '–',
#   'prefix-2': '–',
#   'prefix-3': '–',
#   'suffix-1': '–',
#   'suffix-2': '–',
#   'suffix-3': '–',
#   'prev_word': '»',
#   'next_word': 'Жәнібек',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Жәнібек',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Ж',
#   'prefix-2': 'Жән',
#   'prefix-3': 'Жәні',
#   'suffix-1': 'к',
#   'suffix-2': 'бек',
#   'suffix-3': 'ібек',
#   'prev_word': '–',
#   'next_word': 'қажыға',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қажыға',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қаж',
#   'prefix-3': 'қажы',
#   'suffix-1': 'а',
#   'suffix-2': 'ыға',
#   'suffix-3': 'жыға',
#   'prev_word': 'Жәнібек',
#   'next_word': 'арызын',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'арызын',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ары',
#   'prefix-3': 'арыз',
#   'suffix-1': 'н',
#   'suffix-2': 'зын',
#   'suffix-3': 'ызын',
#   'prev_word': 'қажыға',
#   'next_word': 'айтты',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'айтты',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'айт',
#   'prefix-3': 'айтт',
#   'suffix-1': 'ы',
#   'suffix-2': 'тты',
#   'suffix-3': 'йтты',
#   'prev_word': 'арызын',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'айтты',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Қазақстан',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'Қаз',
#   'prefix-3': 'Қаза',
#   'suffix-1': 'н',
#   'suffix-2': 'тан',
#   'suffix-3': 'стан',
#   'prev_word': '',
#   'next_word': 'көшбасшысының',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'көшбасшысының',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'көш',
#   'prefix-3': 'көшб',
#   'suffix-1': 'ң',
#   'suffix-2': 'ның',
#   'suffix-3': 'ының',
#   'prev_word': 'Қазақстан',
#   'next_word': 'пікірінше',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'пікірінше',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'п',
#   'prefix-2': 'пік',
#   'prefix-3': 'пікі',
#   'suffix-1': 'е',
#   'suffix-2': 'нше',
#   'suffix-3': 'інше',
#   'prev_word': 'көшбасшысының',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'пікірінше',
#   'next_word': 'аталған',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'аталған',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ата',
#   'prefix-3': 'атал',
#   'suffix-1': 'н',
#   'suffix-2': 'ған',
#   'suffix-3': 'лған',
#   'prev_word': ',',
#   'next_word': 'тұжырымдама',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'тұжырымдама',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тұж',
#   'prefix-3': 'тұжы',
#   'suffix-1': 'а',
#   'suffix-2': 'ама',
#   'suffix-3': 'дама',
#   'prev_word': 'аталған',
#   'next_word': 'қағидаттары',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қағидаттары',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қағ',
#   'prefix-3': 'қағи',
#   'suffix-1': 'ы',
#   'suffix-2': 'ары',
#   'suffix-3': 'тары',
#   'prev_word': 'тұжырымдама',
#   'next_word': 'Қазақстанның',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Қазақстанның',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'Қаз',
#   'prefix-3': 'Қаза',
#   'suffix-1': 'ң',
#   'suffix-2': 'ның',
#   'suffix-3': 'нның',
#   'prev_word': 'қағидаттары',
#   'next_word': 'БҰҰ',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'БҰҰ',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'prefix-1': 'Б',
#   'prefix-2': 'БҰҰ',
#   'prefix-3': 'БҰҰ',
#   'suffix-1': 'Ұ',
#   'suffix-2': 'БҰҰ',
#   'suffix-3': 'БҰҰ',
#   'prev_word': 'Қазақстанның',
#   'next_word': 'қолдауымен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': True},
#  {'word': 'қолдауымен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қол',
#   'prefix-3': 'қолд',
#   'suffix-1': 'н',
#   'suffix-2': 'мен',
#   'suffix-3': 'ымен',
#   'prev_word': 'БҰҰ',
#   'next_word': '«',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '«',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '«',
#   'prefix-2': '«',
#   'prefix-3': '«',
#   'suffix-1': '«',
#   'suffix-2': '«',
#   'suffix-3': '«',
#   'prev_word': 'қолдауымен',
#   'next_word': 'Жаңа',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Жаңа',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Ж',
#   'prefix-2': 'Жаң',
#   'prefix-3': 'Жаңа',
#   'suffix-1': 'а',
#   'suffix-2': 'аңа',
#   'suffix-3': 'Жаңа',
#   'prev_word': '«',
#   'next_word': 'Болашақ',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Болашақ',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Б',
#   'prefix-2': 'Бол',
#   'prefix-3': 'Бола',
#   'suffix-1': 'қ',
#   'suffix-2': 'шақ',
#   'suffix-3': 'ашақ',
#   'prev_word': 'Жаңа',
#   'next_word': '»',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '»',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '»',
#   'prefix-2': '»',
#   'prefix-3': '»',
#   'suffix-1': '»',
#   'suffix-2': '»',
#   'suffix-3': '»',
#   'prev_word': 'Болашақ',
#   'next_word': 'тұжырымдамасын',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'тұжырымдамасын',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тұж',
#   'prefix-3': 'тұжы',
#   'suffix-1': 'н',
#   'suffix-2': 'сын',
#   'suffix-3': 'асын',
#   'prev_word': '»',
#   'next_word': 'әзірлеу',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'әзірлеу',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ә',
#   'prefix-2': 'әзі',
#   'prefix-3': 'әзір',
#   'suffix-1': 'у',
#   'suffix-2': 'леу',
#   'suffix-3': 'рлеу',
#   'prev_word': 'тұжырымдамасын',
#   'next_word': 'жөніндегі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жөніндегі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жөн',
#   'prefix-3': 'жөні',
#   'suffix-1': 'і',
#   'suffix-2': 'егі',
#   'suffix-3': 'дегі',
#   'prev_word': 'әзірлеу',
#   'next_word': 'бастамасымен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бастамасымен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бас',
#   'prefix-3': 'баст',
#   'suffix-1': 'н',
#   'suffix-2': 'мен',
#   'suffix-3': 'ымен',
#   'prev_word': 'жөніндегі',
#   'next_word': 'үндеседі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'үндеседі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ү',
#   'prefix-2': 'үнд',
#   'prefix-3': 'үнде',
#   'suffix-1': 'і',
#   'suffix-2': 'еді',
#   'suffix-3': 'седі',
#   'prev_word': 'бастамасымен',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'үндеседі',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Бір',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Б',
#   'prefix-2': 'Бір',
#   'prefix-3': 'Бір',
#   'suffix-1': 'р',
#   'suffix-2': 'Бір',
#   'suffix-3': 'Бір',
#   'prev_word': '',
#   'next_word': 'шарбақтың',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'шарбақтың',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ш',
#   'prefix-2': 'шар',
#   'prefix-3': 'шарб',
#   'suffix-1': 'ң',
#   'suffix-2': 'тың',
#   'suffix-3': 'қтың',
#   'prev_word': 'Бір',
#   'next_word': 'түбіне',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'түбіне',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'түб',
#   'prefix-3': 'түбі',
#   'suffix-1': 'е',
#   'suffix-2': 'іне',
#   'suffix-3': 'біне',
#   'prev_word': 'шарбақтың',
#   'next_word': 'отырып',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'отырып',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'о',
#   'prefix-2': 'оты',
#   'prefix-3': 'отыр',
#   'suffix-1': 'п',
#   'suffix-2': 'рып',
#   'suffix-3': 'ырып',
#   'prev_word': 'түбіне',
#   'next_word': 'дем',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'дем',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'д',
#   'prefix-2': 'дем',
#   'prefix-3': 'дем',
#   'suffix-1': 'м',
#   'suffix-2': 'дем',
#   'suffix-3': 'дем',
#   'prev_word': 'отырып',
#   'next_word': 'алды',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'алды',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'алд',
#   'prefix-3': 'алды',
#   'suffix-1': 'ы',
#   'suffix-2': 'лды',
#   'suffix-3': 'алды',
#   'prev_word': 'дем',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'алды',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'БҰҰ',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'prefix-1': 'Б',
#   'prefix-2': 'БҰҰ',
#   'prefix-3': 'БҰҰ',
#   'suffix-1': 'Ұ',
#   'suffix-2': 'БҰҰ',
#   'suffix-3': 'БҰҰ',
#   'prev_word': '',
#   'next_word': 'Қауіпсіздік',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': True},
#  {'word': 'Қауіпсіздік',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'Қау',
#   'prefix-3': 'Қауі',
#   'suffix-1': 'к',
#   'suffix-2': 'дік',
#   'suffix-3': 'здік',
#   'prev_word': 'БҰҰ',
#   'next_word': 'кеңесінің',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'кеңесінің',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'кең',
#   'prefix-3': 'кеңе',
#   'suffix-1': 'ң',
#   'suffix-2': 'нің',
#   'suffix-3': 'інің',
#   'prev_word': 'Қауіпсіздік',
#   'next_word': 'сол',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'сол',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'с',
#   'prefix-2': 'сол',
#   'prefix-3': 'сол',
#   'suffix-1': 'л',
#   'suffix-2': 'сол',
#   'suffix-3': 'сол',
#   'prev_word': 'кеңесінің',
#   'next_word': 'күні',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'күні',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'күн',
#   'prefix-3': 'күні',
#   'suffix-1': 'і',
#   'suffix-2': 'үні',
#   'suffix-3': 'күні',
#   'prev_word': 'сол',
#   'next_word': 'өткен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'өткен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ө',
#   'prefix-2': 'өтк',
#   'prefix-3': 'өтке',
#   'suffix-1': 'н',
#   'suffix-2': 'кен',
#   'suffix-3': 'ткен',
#   'prev_word': 'күні',
#   'next_word': 'отырыстары',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'отырыстары',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'о',
#   'prefix-2': 'оты',
#   'prefix-3': 'отыр',
#   'suffix-1': 'ы',
#   'suffix-2': 'ары',
#   'suffix-3': 'тары',
#   'prev_word': 'өткен',
#   'next_word': 'аясында',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'аясында',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'аяс',
#   'prefix-3': 'аясы',
#   'suffix-1': 'а',
#   'suffix-2': 'нда',
#   'suffix-3': 'ында',
#   'prev_word': 'отырыстары',
#   'next_word': 'Қ.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Қ.',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'prefix-1': 'Қ',
#   'prefix-2': 'Қ.',
#   'prefix-3': 'Қ.',
#   'suffix-1': '.',
#   'suffix-2': 'Қ.',
#   'suffix-3': 'Қ.',
#   'prev_word': 'аясында',
#   'next_word': 'Әбдірахманов',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Әбдірахманов',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Ә',
#   'prefix-2': 'Әбд',
#   'prefix-3': 'Әбді',
#   'suffix-1': 'в',
#   'suffix-2': 'нов',
#   'suffix-3': 'анов',
#   'prev_word': 'Қ.',
#   'next_word': 'өзінің',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'өзінің',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ө',
#   'prefix-2': 'өзі',
#   'prefix-3': 'өзін',
#   'suffix-1': 'ң',
#   'suffix-2': 'нің',
#   'suffix-3': 'інің',
#   'prev_word': 'Әбдірахманов',
#   'next_word': 'британдық',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'британдық',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бри',
#   'prefix-3': 'брит',
#   'suffix-1': 'қ',
#   'suffix-2': 'дық',
#   'suffix-3': 'ндық',
#   'prev_word': 'өзінің',
#   'next_word': 'әріптесті',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'әріптесті',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ә',
#   'prefix-2': 'әрі',
#   'prefix-3': 'әріп',
#   'suffix-1': 'і',
#   'suffix-2': 'сті',
#   'suffix-3': 'есті',
#   'prev_word': 'британдық',
#   'next_word': 'Борис',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Борис',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Б',
#   'prefix-2': 'Бор',
#   'prefix-3': 'Бори',
#   'suffix-1': 'с',
#   'suffix-2': 'рис',
#   'suffix-3': 'орис',
#   'prev_word': 'әріптесті',
#   'next_word': 'Джонсонмен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Джонсонмен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Д',
#   'prefix-2': 'Джо',
#   'prefix-3': 'Джон',
#   'suffix-1': 'н',
#   'suffix-2': 'мен',
#   'suffix-3': 'нмен',
#   'prev_word': 'Борис',
#   'next_word': 'де',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'де',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'д',
#   'prefix-2': 'де',
#   'prefix-3': 'де',
#   'suffix-1': 'е',
#   'suffix-2': 'де',
#   'suffix-3': 'де',
#   'prev_word': 'Джонсонмен',
#   'next_word': 'кездесу',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'кездесу',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'кез',
#   'prefix-3': 'кезд',
#   'suffix-1': 'у',
#   'suffix-2': 'есу',
#   'suffix-3': 'десу',
#   'prev_word': 'де',
#   'next_word': 'өткізді',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'өткізді',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ө',
#   'prefix-2': 'өтк',
#   'prefix-3': 'өткі',
#   'suffix-1': 'і',
#   'suffix-2': 'зді',
#   'suffix-3': 'ізді',
#   'prev_word': 'кездесу',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'өткізді',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Соның',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'С',
#   'prefix-2': 'Сон',
#   'prefix-3': 'Соны',
#   'suffix-1': 'ң',
#   'suffix-2': 'ның',
#   'suffix-3': 'оның',
#   'prev_word': '',
#   'next_word': 'үшін',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'үшін',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ү',
#   'prefix-2': 'үші',
#   'prefix-3': 'үшін',
#   'suffix-1': 'н',
#   'suffix-2': 'шін',
#   'suffix-3': 'үшін',
#   'prev_word': 'Соның',
#   'next_word': 'Мүсірәлі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Мүсірәлі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'М',
#   'prefix-2': 'Мүс',
#   'prefix-3': 'Мүсі',
#   'suffix-1': 'і',
#   'suffix-2': 'әлі',
#   'suffix-3': 'рәлі',
#   'prev_word': 'үшін',
#   'next_word': 'байға',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'байға',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бай',
#   'prefix-3': 'байғ',
#   'suffix-1': 'а',
#   'suffix-2': 'йға',
#   'suffix-3': 'айға',
#   'prev_word': 'Мүсірәлі',
#   'next_word': 'бір',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бір',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бір',
#   'prefix-3': 'бір',
#   'suffix-1': 'р',
#   'suffix-2': 'бір',
#   'suffix-3': 'бір',
#   'prev_word': 'байға',
#   'next_word': 'жақсы',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жақсы',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жақ',
#   'prefix-3': 'жақс',
#   'suffix-1': 'ы',
#   'suffix-2': 'қсы',
#   'suffix-3': 'ақсы',
#   'prev_word': 'бір',
#   'next_word': 'ат',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ат',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ат',
#   'prefix-3': 'ат',
#   'suffix-1': 'т',
#   'suffix-2': 'ат',
#   'suffix-3': 'ат',
#   'prev_word': 'жақсы',
#   'next_word': 'сый',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'сый',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'с',
#   'prefix-2': 'сый',
#   'prefix-3': 'сый',
#   'suffix-1': 'й',
#   'suffix-2': 'сый',
#   'suffix-3': 'сый',
#   'prev_word': 'ат',
#   'next_word': 'қылады',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қылады',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қыл',
#   'prefix-3': 'қыла',
#   'suffix-1': 'ы',
#   'suffix-2': 'ады',
#   'suffix-3': 'лады',
#   'prev_word': 'сый',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
# ...
#   'capitals_inside': False},
#  {'word': 'кезінде',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'к',
#   'prefix-2': 'кез',
#   'prefix-3': 'кезі',
#   'suffix-1': 'е',
#   'suffix-2': 'нде',
#   'suffix-3': 'інде',
#   'prev_word': 'өткізу',
#   'next_word': 'құқықтық',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'құқықтық',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'құқ',
#   'prefix-3': 'құқы',
#   'suffix-1': 'қ',
#   'suffix-2': 'тық',
#   'suffix-3': 'қтық',
#   'prev_word': 'кезінде',
#   'next_word': 'тәртіпті',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'тәртіпті',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тәр',
#   'prefix-3': 'тәрт',
#   'suffix-1': 'і',
#   'suffix-2': 'пті',
#   'suffix-3': 'іпті',
#   'prev_word': 'құқықтық',
#   'next_word': 'қамтамасыз',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қамтамасыз',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қам',
#   'prefix-3': 'қамт',
#   'suffix-1': 'з',
#   'suffix-2': 'сыз',
#   'suffix-3': 'асыз',
#   'prev_word': 'тәртіпті',
#   'next_word': 'етуге',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'етуге',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'е',
#   'prefix-2': 'ету',
#   'prefix-3': 'етуг',
#   'suffix-1': 'е',
#   'suffix-2': 'уге',
#   'suffix-3': 'туге',
#   'prev_word': 'қамтамасыз',
#   'next_word': 'жеке',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жеке',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жек',
#   'prefix-3': 'жеке',
#   'suffix-1': 'е',
#   'suffix-2': 'еке',
#   'suffix-3': 'жеке',
#   'prev_word': 'етуге',
#   'next_word': 'құрамнан',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'құрамнан',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'құр',
#   'prefix-3': 'құра',
#   'suffix-1': 'н',
#   'suffix-2': 'нан',
#   'suffix-3': 'мнан',
#   'prev_word': 'жеке',
#   'next_word': '1200',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '1200',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '1',
#   'prefix-2': '120',
#   'prefix-3': '1200',
#   'suffix-1': '0',
#   'suffix-2': '200',
#   'suffix-3': '1200',
#   'prev_word': 'құрамнан',
#   'next_word': 'әскери',
#   'has_hyphen': False,
#   'is_numeric': True,
#   'capitals_inside': False},
#  {'word': 'әскери',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ә',
#   'prefix-2': 'әск',
#   'prefix-3': 'әске',
#   'suffix-1': 'и',
#   'suffix-2': 'ери',
#   'suffix-3': 'кери',
#   'prev_word': '1200',
#   'next_word': 'қызметші',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қызметші',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қыз',
#   'prefix-3': 'қызм',
#   'suffix-1': 'і',
#   'suffix-2': 'тші',
#   'suffix-3': 'етші',
#   'prev_word': 'әскери',
#   'next_word': 'қатыстырылмақ',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'қатыстырылмақ',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'қ',
#   'prefix-2': 'қат',
#   'prefix-3': 'қаты',
#   'suffix-1': 'қ',
#   'suffix-2': 'мақ',
#   'suffix-3': 'лмақ',
#   'prev_word': 'қызметші',
#   'next_word': '»',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '»',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '»',
#   'prefix-2': '»',
#   'prefix-3': '»',
#   'suffix-1': '»',
#   'suffix-2': '»',
#   'suffix-3': '»',
#   'prev_word': 'қатыстырылмақ',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': '»',
#   'next_word': 'деді',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'деді',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'д',
#   'prefix-2': 'дед',
#   'prefix-3': 'деді',
#   'suffix-1': 'і',
#   'suffix-2': 'еді',
#   'suffix-3': 'деді',
#   'prev_word': ',',
#   'next_word': 'М.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'М.',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': False,
#   'prefix-1': 'М',
#   'prefix-2': 'М.',
#   'prefix-3': 'М.',
#   'suffix-1': '.',
#   'suffix-2': 'М.',
#   'suffix-3': 'М.',
#   'prev_word': 'деді',
#   'next_word': 'Сатов',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Сатов',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'С',
#   'prefix-2': 'Сат',
#   'prefix-3': 'Сато',
#   'suffix-1': 'в',
#   'suffix-2': 'тов',
#   'suffix-3': 'атов',
#   'prev_word': 'М.',
#   'next_word': '.',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '.',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '.',
#   'prefix-2': '.',
#   'prefix-3': '.',
#   'suffix-1': '.',
#   'suffix-2': '.',
#   'suffix-3': '.',
#   'prev_word': 'Сатов',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '«',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '«',
#   'prefix-2': '«',
#   'prefix-3': '«',
#   'suffix-1': '«',
#   'suffix-2': '«',
#   'suffix-3': '«',
#   'prev_word': '',
#   'next_word': 'Самрұқ-Қазына',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Самрұқ-Қазына',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'С',
#   'prefix-2': 'Сам',
#   'prefix-3': 'Самр',
#   'suffix-1': 'а',
#   'suffix-2': 'ына',
#   'suffix-3': 'зына',
#   'prev_word': '«',
#   'next_word': '»',
#   'has_hyphen': True,
#   'is_numeric': False,
#   'capitals_inside': True},
#  {'word': '»',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '»',
#   'prefix-2': '»',
#   'prefix-3': '»',
#   'suffix-1': '»',
#   'suffix-2': '»',
#   'suffix-3': '»',
#   'prev_word': 'Самрұқ-Қазына',
#   'next_word': 'ұсынған',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ұсынған',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ұ',
#   'prefix-2': 'ұсы',
#   'prefix-3': 'ұсын',
#   'suffix-1': 'н',
#   'suffix-2': 'ған',
#   'suffix-3': 'нған',
#   'prev_word': '»',
#   'next_word': 'алдын',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'алдын',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'алд',
#   'prefix-3': 'алды',
#   'suffix-1': 'н',
#   'suffix-2': 'дын',
#   'suffix-3': 'лдын',
#   'prev_word': 'ұсынған',
#   'next_word': 'ала',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ала',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ала',
#   'prefix-3': 'ала',
#   'suffix-1': 'а',
#   'suffix-2': 'ала',
#   'suffix-3': 'ала',
#   'prev_word': 'алдын',
#   'next_word': 'біліктілік',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'біліктілік',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'біл',
#   'prefix-3': 'білі',
#   'suffix-1': 'к',
#   'suffix-2': 'лік',
#   'suffix-3': 'ілік',
#   'prev_word': 'ала',
#   'next_word': 'тұрғысынан',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'тұрғысынан',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тұр',
#   'prefix-3': 'тұрғ',
#   'suffix-1': 'н',
#   'suffix-2': 'нан',
#   'suffix-3': 'ынан',
#   'prev_word': 'біліктілік',
#   'next_word': 'іріктеу',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'іріктеу',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'і',
#   'prefix-2': 'ірі',
#   'prefix-3': 'ірік',
#   'suffix-1': 'у',
#   'suffix-2': 'теу',
#   'suffix-3': 'ктеу',
#   'prev_word': 'тұрғысынан',
#   'next_word': 'мәселесі',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'мәселесі',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'м',
#   'prefix-2': 'мәс',
#   'prefix-3': 'мәсе',
#   'suffix-1': 'і',
#   'suffix-2': 'есі',
#   'suffix-3': 'лесі',
#   'prev_word': 'іріктеу',
#   'next_word': '«',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '«',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '«',
#   'prefix-2': '«',
#   'prefix-3': '«',
#   'suffix-1': '«',
#   'suffix-2': '«',
#   'suffix-3': '«',
#   'prev_word': 'мәселесі',
#   'next_word': 'Атамекенде',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Атамекенде',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'А',
#   'prefix-2': 'Ата',
#   'prefix-3': 'Атам',
#   'suffix-1': 'е',
#   'suffix-2': 'нде',
#   'suffix-3': 'енде',
#   'prev_word': '«',
#   'next_word': '»',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '»',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '»',
#   'prefix-2': '»',
#   'prefix-3': '»',
#   'suffix-1': '»',
#   'suffix-2': '»',
#   'suffix-3': '»',
#   'prev_word': 'Атамекенде',
#   'next_word': 'талқыланды',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'талқыланды',
#   'is_first': False,
#   'is_last': True,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тал',
#   'prefix-3': 'талқ',
#   'suffix-1': 'ы',
#   'suffix-2': 'нды',
#   'suffix-3': 'анды',
#   'prev_word': '»',
#   'next_word': '',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Жұман',
#   'is_first': True,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'Ж',
#   'prefix-2': 'Жұм',
#   'prefix-3': 'Жұма',
#   'suffix-1': 'н',
#   'suffix-2': 'ман',
#   'suffix-3': 'ұман',
#   'prev_word': '',
#   'next_word': 'ашуланғансып',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'ашуланғансып',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'а',
#   'prefix-2': 'ашу',
#   'prefix-3': 'ашул',
#   'suffix-1': 'п',
#   'suffix-2': 'сып',
#   'suffix-3': 'нсып',
#   'prev_word': 'Жұман',
#   'next_word': ',',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ',',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ',',
#   'prefix-2': ',',
#   'prefix-3': ',',
#   'suffix-1': ',',
#   'suffix-2': ',',
#   'suffix-3': ',',
#   'prev_word': 'ашуланғансып',
#   'next_word': 'жайымен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жайымен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жай',
#   'prefix-3': 'жайы',
#   'suffix-1': 'н',
#   'suffix-2': 'мен',
#   'suffix-3': 'ымен',
#   'prev_word': ',',
#   'next_word': 'отырып',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'отырып',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'о',
#   'prefix-2': 'оты',
#   'prefix-3': 'отыр',
#   'suffix-1': 'п',
#   'suffix-2': 'рып',
#   'suffix-3': 'ырып',
#   'prev_word': 'жайымен',
#   'next_word': ':',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': ':',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': ':',
#   'prefix-2': ':',
#   'prefix-3': ':',
#   'suffix-1': ':',
#   'suffix-2': ':',
#   'suffix-3': ':',
#   'prev_word': 'отырып',
#   'next_word': '«',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': '«',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': True,
#   'is_all_lower': True,
#   'prefix-1': '«',
#   'prefix-2': '«',
#   'prefix-3': '«',
#   'suffix-1': '«',
#   'suffix-2': '«',
#   'suffix-3': '«',
#   'prev_word': ':',
#   'next_word': 'Сен',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'Сен',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': True,
#   'is_all_caps': False,
#   'is_all_lower': False,
#   'prefix-1': 'С',
#   'prefix-2': 'Сен',
#   'prefix-3': 'Сен',
#   'suffix-1': 'н',
#   'suffix-2': 'Сен',
#   'suffix-3': 'Сен',
#   'prev_word': '«',
#   'next_word': 'бір',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'бір',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'б',
#   'prefix-2': 'бір',
#   'prefix-3': 'бір',
#   'suffix-1': 'р',
#   'suffix-2': 'бір',
#   'suffix-3': 'бір',
#   'prev_word': 'Сен',
#   'next_word': 'таяқ',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'таяқ',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'т',
#   'prefix-2': 'тая',
#   'prefix-3': 'таяқ',
#   'suffix-1': 'қ',
#   'suffix-2': 'аяқ',
#   'suffix-3': 'таяқ',
#   'prev_word': 'бір',
#   'next_word': 'жемей',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  {'word': 'жемей',
#   'is_first': False,
#   'is_last': False,
#   'is_capitalized': False,
#   'is_all_caps': False,
#   'is_all_lower': True,
#   'prefix-1': 'ж',
#   'prefix-2': 'жем',
#   'prefix-3': 'жеме',
#   'suffix-1': 'й',
#   'suffix-2': 'мей',
#   'suffix-3': 'емей',
#   'prev_word': 'таяқ',
#   'next_word': 'басылмассың',
#   'has_hyphen': False,
#   'is_numeric': False,
#   'capitals_inside': False},
#  ...]

# %%
y_train
# Out:
# ['PROPN',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'NUM',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'CONJ',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'AUX',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'ADJ',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'ADV',
#  'PUNCT',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'PUNCT',
#  'ADJ',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'ADP',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'ADP',
#  'PROPN',
#  'NOUN',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'PRON',
#  'ADP',
#  'VERB',
#  'AUX',
#  'AUX',
#  'PUNCT',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PRON',
#  'ADP',
#  'PUNCT',
#  'PUNCT',
#  'NUM',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'CONJ',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NUM',
#  'NUM',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'ADV',
#  'VERB',
#  'ADP',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'SCONJ',
#  'PROPN',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'ADJ',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'NUM',
#  'PUNCT',
#  'CONJ',
#  'ADP',
#  'PROPN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'VERB',
#  'ADV',
#  'PRON',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'SCONJ',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  'NUM',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'ADV',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'VERB',
#  'ADJ',
#  'PROPN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'PUNCT',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'PROPN',
#  'NUM',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'NOUN',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'CONJ',
#  'ADV',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'CONJ',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'PROPN',
#  'PUNCT',
#  'ADV',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'ADJ',
#  'NOUN',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'VERB',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'CONJ',
#  'PROPN',
#  'PROPN',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'PUNCT',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'NUM',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'ADJ',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'PROPN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'ADP',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PROPN',
#  'VERB',
#  'PRON',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'PRON',
#  'ADP',
#  'NUM',
#  'NOUN',
#  'ADP',
#  'PUNCT',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'ADJ',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'VERB',
#  'ADV',
#  'PROPN',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'ADV',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'PUNCT',
#  'SCONJ',
#  'PRON',
#  'ADV',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'CONJ',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'PROPN',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'CONJ',
#  'PUNCT',
#  'ADP',
#  'PRON',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'ADV',
#  'VERB',
#  'CONJ',
#  'VERB',
#  'NOUN',
#  'NUM',
#  'NUM',
#  'PROPN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'ADJ',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'CONJ',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'PUNCT',
#  'ADV',
#  'PUNCT',
#  'ADV',
#  'PRON',
#  'VERB',
#  'ADP',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'PROPN',
#  'ADP',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'ADP',
#  'ADV',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADP',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'VERB',
#  'ADP',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PROPN',
#  'NUM',
#  'NUM',
#  'ADJ',
#  'ADJ',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'PUNCT',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'ADJ',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'ADJ',
#  'CONJ',
#  'ADJ',
#  'PROPN',
#  'ADP',
#  'ADJ',
#  'VERB',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'NOUN',
#  'PROPN',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'VERB',
#  'VERB',
#  'PUNCT',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'CONJ',
#  'PROPN',
#  'NOUN',
#  'PROPN',
#  'PROPN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'CONJ',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'PRON',
#  'ADV',
#  'ADV',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'PUNCT',
#  'ADV',
#  'PROPN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'PRON',
#  'PUNCT',
#  'PRON',
#  'PRON',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'ADJ',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'ADJ',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'ADV',
#  'NOUN',
#  'ADV',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NUM',
#  'PUNCT',
#  'X',
#  'NOUN',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NUM',
#  'NOUN',
#  'VERB',
#  'ADJ',
#  'NOUN',
#  'ADJ',
#  'PUNCT',
#  'PROPN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'PRON',
#  'VERB',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PROPN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'PRON',
#  'ADJ',
#  'PUNCT',
#  'NOUN',
#  'NOUN',
#  'NOUN',
#  'PUNCT',
#  'CONJ',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'ADP',
#  'ADP',
#  'PUNCT',
#  'NOUN',
#  'PUNCT',
#  'PRON',
#  'NOUN',
#  'NUM',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'AUX',
#  'PUNCT',
#  'SCONJ',
#  'NUM',
#  'ADJ',
#  'ADJ',
#  'PROPN',
#  'VERB',
#  'NOUN',
#  'ADJ',
#  'NOUN',
#  'ADV',
#  'VERB',
#  'ADJ',
#  'NOUN',
#  'NUM',
#  'ADJ',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'VERB',
#  'PROPN',
#  'PROPN',
#  'PUNCT',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'VERB',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'NOUN',
#  'VERB',
#  'NOUN',
#  'PUNCT',
#  'PROPN',
#  'PUNCT',
#  'VERB',
#  'PROPN',
#  'VERB',
#  'PUNCT',
#  'NOUN',
#  'VERB',
#  'PUNCT',
#  'PUNCT',
#  'PRON',
#  'NUM',
#  'NOUN',
#  'VERB',
#  ...]

# %%
len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (702419, 702419, 232312, 232312)

# %%
clf = Pipeline([
    ('vectorizer', DictVectorizer(sparse=False)),
    ('classifier', DecisionTreeClassifier(criterion='entropy'))
])

# %%
clf.fit(X_train[:40000], y_train[:40000])  # Limit to 40K samples
print('Training completed')
# Out:
# Training completed

# %%
print("Accuracy:", clf.score(X_test[:20000], y_test[:20000]))
# Out:
# Accuracy: 0.89605

# %%
dump(clf, 'Kazakh_POS_Tagger.joblib')
# Out:
# ['Kazakh_POS_Tagger.joblib']

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
def pos_tag(sentence):
    tags = clf.predict([features(sentence, index) for index in range(len(sentence))])
    return list(zip(sentence, tags))

# %%
from nltk import word_tokenize
print(pos_tag(word_tokenize('Еңбек етсең ерінбей, тояды қарның тіленбей.')))
# Out:
# [('Еңбек', 'NOUN'), ('етсең', 'NOUN'), ('ерінбей', 'VERB'), (',', 'PUNCT'), ('тояды', 'NOUN'), ('қарның', 'NOUN'), ('тіленбей', 'AUX'), ('.', 'PUNCT')]

# %% [markdown]
# # NLTK approach

# %%
import nltk
from nltk.tag import UnigramTagger, BigramTagger, TrigramTagger
from nltk.corpus.reader import TaggedCorpusReader

# %%
train_data = []
sent = []
for w, t in zip(X_train, y_train):
    if not w['is_last']:
        sent.append((w['word'], t))
    else:
        sent.append((w['word'], t))
        train_data.append(sent)
        sent = []
    #print((w['word'], t))

test_data = []
sent = []
for w, t in zip(X_test, y_test):
    if not w['is_last']:
        sent.append((w['word'], t))
    else:
        sent.append((w['word'], t))
        test_data.append(sent)
        sent = []

# %%
test_data
# Out:
# [[('Қос', 'ADJ'),
#   ('қабат', 'NOUN'),
#   ('тас', 'NOUN'),
#   ('болат', 'NOUN'),
#   ('үйдің', 'NOUN'),
#   ('үстіңгі', 'ADJ'),
#   ('бөлмесінде', 'NOUN'),
#   ('электр', 'NOUN'),
#   ('нұрына', 'NOUN'),
#   ('шомылып', 'VERB'),
#   (',', 'PUNCT'),
#   ('қара', 'ADJ'),
#   ('шолақ', 'ADJ'),
#   ('бешпетін', 'NOUN'),
#   ('жамылып', 'VERB'),
#   (',', 'PUNCT'),
#   ('Архимед', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Торилел', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Пифагор', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Ньютон', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Богданов', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Каутский', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Уйпперлермен', 'PROPN'),
#   ('айналысып', 'VERB'),
#   (',', 'PUNCT'),
#   ('терең', 'ADJ'),
#   ('ойға', 'NOUN'),
#   ('бойлап', 'VERB'),
#   ('отырған', 'AUX'),
#   ('қошқыл', 'ADJ'),
#   ('жігіт', 'NOUN'),
#   ('кім', 'PRON'),
#   ('?', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Сен', 'PRON'),
#   ('салар', 'VERB'),
#   ('да', 'ADP'),
#   (',', 'PUNCT'),
#   ('мен', 'PRON'),
#   ('салар', 'VERB'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('бәрі', 'PRON'),
#   ('де', 'ADP'),
#   ('енжар', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('туралы', 'ADP'),
#   ('ҚР', 'PROPN'),
#   ('Үкіметінде', 'PROPN'),
#   ('өткен', 'VERB'),
#   ('селекторлық', 'ADJ'),
#   ('отырыс', 'NOUN'),
#   ('барысында', 'ADP'),
#   ('Министрлер', 'NOUN'),
#   ('кабинетінің', 'NOUN'),
#   ('басшысы', 'NOUN'),
#   ('Кәрім', 'PROPN'),
#   ('Мәсімов', 'PROPN'),
#   ('айтты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Әзімбай', 'PROPN'),
#   ('көрпеге', 'NOUN'),
#   ('кірді', 'VERB'),
#   ('де', 'ADP'),
#   (',', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('жеңге', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('жұлмалай', 'VERB'),
#   ('бастады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Еліміздің', 'NOUN'),
#   ('барлық', 'PRON'),
#   ('өңірлерінде', 'NOUN'),
#   ('балаларды', 'NOUN'),
#   ('оқытудың', 'VERB'),
#   ('және', 'CONJ'),
#   ('тәрбие', 'NOUN'),
#   ('берудің', 'VERB'),
#   ('жаңашыл', 'ADJ'),
#   ('инновациялық', 'ADJ'),
#   ('тәсілдерін', 'NOUN'),
#   ('табысты', 'ADJ'),
#   ('енгізіп', 'VERB'),
#   ('келе', 'AUX'),
#   ('жатқан', 'AUX'),
#   ('19', 'NUM'),
#   ('Назарбаев', 'PROPN'),
#   ('зияткерлік', 'ADJ'),
#   ('мектебі', 'NOUN'),
#   ('құрылып', 'VERB'),
#   (',', 'PUNCT'),
#   ('жұмыс', 'NOUN'),
#   ('істеуде', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бір', 'NUM'),
#   ('сиырдың', 'NOUN'),
#   ('орташа', 'ADJ'),
#   ('сауынынан', 'NOUN'),
#   ('30', 'NUM'),
#   ('-', 'PUNCT'),
#   ('32', 'NUM'),
#   ('литр', 'NOUN'),
#   ('сүт', 'NOUN'),
#   ('алынады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('32', 'NUM'),
#   ('жастағы', 'ADJ'),
#   ('әйел', 'NOUN'),
#   ('қаңтардың', 'NOUN'),
#   ('16-сы', 'NUM'),
#   ('күні', 'NOUN'),
#   ('өмірге', 'NOUN'),
#   ('келген', 'VERB'),
#   ('ұлын', 'NOUN'),
#   ('құрбысының', 'NOUN'),
#   ('танысына', 'NOUN'),
#   ('сатып', 'VERB'),
#   ('жатқан', 'AUX'),
#   ('жерінен', 'NOUN'),
#   ('ұсталған', 'VERB'),
#   ('болатын', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('мәселе', 'NOUN'),
#   ('әкімдіктің', 'NOUN'),
#   ('қолдауынсыз', 'ADV'),
#   ('мүмкін', 'ADJ'),
#   ('емес', 'VERB'),
#   (',', 'PUNCT'),
#   ('толықтай', 'ADJ'),
#   ('демеу', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('байланыс', 'NOUN'),
#   ('қажет', 'ADJ'),
#   ('»', 'PUNCT'),
#   ('.', 'PUNCT')],
#  [('VI', 'NUM'),
#   ('Мұхаммед', 'PROPN'),
#   ('Нұрсұлтан', 'PROPN'),
#   ('Назарбаевты', 'PROPN'),
#   ('Қазақстан', 'PROPN'),
#   ('Республикасының', 'PROPN'),
#   ('Президенті', 'PROPN'),
#   ('лауазымына', 'NOUN'),
#   ('қайта', 'ADV'),
#   ('сайлануымен', 'VERB'),
#   ('құттықтап', 'VERB'),
#   (',', 'PUNCT'),
#   ('оның', 'PRON'),
#   ('елді', 'NOUN'),
#   ('әрі', 'ADV'),
#   ('қарай', 'ADP'),
#   ('дамыту', 'VERB'),
#   ('мен', 'CONJ'),
#   ('өркендетуге', 'VERB'),
#   ('бағытталған', 'VERB'),
#   ('барлық', 'PRON'),
#   ('бастамаларына', 'NOUN'),
#   ('табыс', 'NOUN'),
#   ('тіледі', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Жиналған', 'VERB'),
#   ('жазушылар', 'NOUN'),
#   ('өздерінің', 'PRON'),
#   ('шетелдіктерге', 'NOUN'),
#   ('жерді', 'NOUN'),
#   ('жалға', 'NOUN'),
#   ('беруге', 'VERB'),
#   ('қарсы', 'ADJ'),
#   ('екенін', 'VERB'),
#   ('мәлімдеп', 'VERB'),
#   (',', 'PUNCT'),
#   ('осы', 'PRON'),
#   ('баптардың', 'NOUN'),
#   ('қолданыстағы', 'ADJ'),
#   ('заңнан', 'NOUN'),
#   ('алынып', 'VERB'),
#   ('тасталуын', 'AUX'),
#   ('талап', 'NOUN'),
#   ('етті', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бітірушілердің', 'NOUN'),
#   ('6291-і', 'NUM'),
#   ('қазақ', 'NOUN'),
#   ('тілінде', 'NOUN'),
#   (',', 'PUNCT'),
#   ('2245-і', 'NUM'),
#   ('орыс', 'NOUN'),
#   ('тілінде', 'NOUN'),
#   (',', 'PUNCT'),
#   ('25-і', 'NUM'),
#   ('өзбек', 'NOUN'),
#   ('тілінде', 'NOUN'),
#   ('оқығандар', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Тексеру', 'NOUN'),
#   ('жүргізу', 'VERB'),
#   ('барысында', 'ADP'),
#   ('тасымалдаушыларда', 'NOUN'),
#   ('көлік', 'NOUN'),
#   ('құралына', 'NOUN'),
#   ('техникалық', 'ADJ'),
#   ('байқау', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('азаматтық-құқықтық', 'ADJ'),
#   ('жауапкершілікті', 'ADJ'),
#   ('міндетті', 'ADJ'),
#   ('сақтандыру', 'VERB'),
#   ('болмай', 'VERB'),
#   ('шықты', 'AUX'),
#   (',', 'PUNCT'),
#   ('сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   (',', 'PUNCT'),
#   ('қажет', 'ADJ'),
#   ('рұқсат', 'NOUN'),
#   ('құжаттар', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('келісулер', 'NOUN'),
#   ('де', 'ADP'),
#   ('табылмады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Көп', 'ADV'), ('жасасын', 'VERB'), ('аналар', 'NOUN'), ('!', 'PUNCT')],
#  [('Бекболат', 'PROPN'),
#   ('Тыпаңды', 'PROPN'),
#   ('тани', 'VERB'),
#   ('кетті', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Наганода', 'PROPN'),
#   ('өткен', 'VERB'),
#   ('қысқы', 'ADJ'),
#   ('Олимпиада', 'PROPN'),
#   ('ойындарының', 'NOUN'),
#   ('қола', 'NOUN'),
#   ('жүлдегері', 'NOUN'),
#   ('Л.', 'PROPN'),
#   ('Прокашева', 'PROPN'),
#   ('Президенттің', 'PROPN'),
#   ('сайлаудағы', 'ADJ'),
#   ('күмәнсіз', 'ADJ'),
#   ('әрі', 'CONJ'),
#   ('айқын', 'ADJ'),
#   ('жеңісі', 'NOUN'),
#   ('барша', 'PRON'),
#   ('қазақстандықтардың', 'NOUN'),
#   ('таңдаған', 'VERB'),
#   ('саяси', 'ADJ'),
#   ('бағыттың', 'NOUN'),
#   ('дұрыстығына', 'NOUN'),
#   ('деген', 'VERB'),
#   ('терең', 'ADJ'),
#   ('сенімінің', 'NOUN'),
#   ('жемісі', 'NOUN'),
#   ('әрі', 'CONJ'),
#   ('бүкіл', 'PRON'),
#   ('халықтық', 'ADJ'),
#   ('сенімнің', 'NOUN'),
#   ('көрінісі', 'NOUN'),
#   ('екенін', 'VERB'),
#   ('атап', 'VERB'),
#   ('өткен', 'AUX'),
#   ('.', 'PUNCT')],
#  [('20', 'NUM'),
#   ('мың', 'NUM'),
#   ('теңгелік', 'ADJ'),
#   ('банкнот', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('тұңғыш', 'ADJ'),
#   ('президент', 'NOUN'),
#   ('күніне', 'NOUN'),
#   ('тарту', 'NOUN')],
#  [('Еске', 'NOUN'),
#   ('салайық', 'VERB'),
#   (',', 'PUNCT'),
#   ('Мемлекет', 'PROPN'),
#   ('басшысы', 'NOUN'),
#   ('Нұрсұлтан', 'PROPN'),
#   ('Назарбаев', 'PROPN'),
#   ('ҚР', 'PROPN'),
#   ('Жер', 'NOUN'),
#   ('кодексіне', 'NOUN'),
#   ('енгізілетін', 'VERB'),
#   ('өзгерістерге', 'NOUN'),
#   ('мораторий', 'NOUN'),
#   ('жариялап', 'VERB'),
#   (',', 'PUNCT'),
#   ('құрылған', 'VERB'),
#   ('комиссияға', 'NOUN'),
#   ('мемлекеттік', 'ADJ'),
#   ('органдармен', 'NOUN'),
#   (',', 'PUNCT'),
#   ('қоғамдық', 'ADJ'),
#   ('ұйымдармен', 'NOUN'),
#   ('бірлесе', 'VERB'),
#   ('отырып', 'AUX'),
#   ('аталған', 'VERB'),
#   ('мәселені', 'NOUN'),
#   ('талқылап', 'VERB'),
#   (',', 'PUNCT'),
#   ('қорытындысын', 'NOUN'),
#   ('шығарып', 'VERB'),
#   (',', 'PUNCT'),
#   ('өз', 'PRON'),
#   ('ұсыныстарына', 'NOUN'),
#   ('Парламентке', 'PROPN'),
#   ('білдіруді', 'VERB'),
#   ('тапсырды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Р.', 'PROPN'),
#   ('Кастро', 'PROPN'),
#   ('Қазақстан', 'PROPN'),
#   ('Президентіне', 'PROPN'),
#   ('риясыз', 'ADJ'),
#   ('құттықтауын', 'NOUN'),
#   ('жолдап', 'VERB'),
#   (',', 'PUNCT'),
#   ('екі', 'NUM'),
#   ('ел', 'NOUN'),
#   ('арасындағы', 'ADJ'),
#   ('қарым-қатынасты', 'NOUN'),
#   ('одан', 'PRON'),
#   ('әрі', 'ADV'),
#   ('дамытуға', 'VERB'),
#   ('ниетті', 'ADJ'),
#   ('екенін', 'VERB'),
#   ('білдірді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ең', 'ADV'),
#   ('еті', 'NOUN'),
#   ('тәттісі', 'ADJ'),
#   ('–', 'PUNCT'),
#   ('балшықшы', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Қазақстан', 'PROPN'),
#   ('Республикасының', 'PROPN'),
#   ('Мемлекеттік', 'ADJ'),
#   ('хатшысы', 'NOUN'),
#   ('Гүлшара', 'PROPN'),
#   ('Әбдіқалықова', 'PROPN'),
#   ('бірқатар', 'PRON'),
#   ('елшілерден', 'NOUN'),
#   ('сенім', 'NOUN'),
#   ('грамоталарын', 'NOUN'),
#   ('қабылдады', 'VERB')],
#  [('Деген', 'VERB'),
#   ('шеке', 'NOUN'),
#   ('қызар', 'VERB'),
#   (',', 'PUNCT'),
#   ('ми', 'NOUN'),
#   ('қайнар', 'VERB'),
#   ('уақыт', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Елдеріміз', 'NOUN'),
#   ('арасындағы', 'ADJ'),
#   ('ынтымақтастықты', 'NOUN'),
#   ('болашақта', 'NOUN'),
#   ('да', 'ADP'),
#   ('нығайта', 'VERB'),
#   ('беруге', 'VERB'),
#   ('деген', 'VERB'),
#   ('шынайы', 'ADJ'),
#   ('ықыласымды', 'NOUN'),
#   ('қабыл', 'NOUN'),
#   ('алыңыз', 'VERB'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('делінген', 'VERB'),
#   ('жеделхатта', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Айта', 'VERB'),
#   ('кетейік', 'AUX'),
#   (',', 'PUNCT'),
#   ('аталмыш', 'VERB'),
#   ('жоба', 'NOUN'),
#   ('Қазақстанда', 'PROPN'),
#   ('алғаш', 'ADJ'),
#   ('рет', 'NOUN'),
#   ('былтыр', 'ADV'),
#   ('өткен', 'VERB'),
#   ('болатын', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Елдің', 'NOUN'),
#   ('байлығын', 'NOUN'),
#   (',', 'PUNCT'),
#   ('қанын', 'NOUN'),
#   ('сорып', 'VERB'),
#   (',', 'PUNCT'),
#   ('малайдың', 'NOUN'),
#   ('еңбегін', 'NOUN'),
#   ('жеп', 'VERB'),
#   ('бай', 'NOUN'),
#   ('болады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Нұрлы', 'ADJ'),
#   ('жол', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('бағдарламасы', 'NOUN'),
#   ('аясында', 'NOUN'),
#   ('жолдар', 'NOUN'),
#   (',', 'PUNCT'),
#   ('әуежайлар', 'NOUN'),
#   ('салынатын', 'VERB'),
#   ('болады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Нәтижесінде', 'NOUN'),
#   ('республикалық', 'ADJ'),
#   ('картаға', 'NOUN'),
#   ('қайсысы', 'PRON'),
#   ('енетінін', 'VERB'),
#   (',', 'PUNCT'),
#   ('ал', 'SCONJ'),
#   ('облыстық', 'ADJ'),
#   ('картаға', 'NOUN'),
#   ('қайсысы', 'PRON'),
#   ('кіретінін', 'VERB'),
#   ('қарастыруымыз', 'VERB'),
#   ('керек', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Құдайекең', 'PROPN'),
#   ('қырына', 'NOUN'),
#   ('бір', 'NUM'),
#   ('алса', 'VERB'),
#   (',', 'PUNCT'),
#   ('жуырда', 'ADV'),
#   ('оңдырған', 'VERB'),
#   ('ба', 'PART'),
#   ('?', 'PUNCT')],
#  [('2014', 'NUM'),
#   ('жылы', 'NOUN'),
#   ('Қазақстан', 'PROPN'),
#   ('70-ші', 'NUM'),
#   ('мемлекет', 'NOUN'),
#   ('болып', 'VERB'),
#   ('тіркелді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Қыз', 'NOUN'),
#   ('табылмай', 'VERB'),
#   (',', 'PUNCT'),
#   ('сандалып', 'VERB'),
#   (',', 'PUNCT'),
#   ('долданып', 'VERB'),
#   ('қайтқан', 'VERB'),
#   ('үш', 'NUM'),
#   ('орыс', 'NOUN'),
#   ('бәйбішені', 'NOUN'),
#   ('терезе', 'NOUN'),
#   ('алдына', 'NOUN'),
#   ('етпетінен', 'NOUN'),
#   ('басып', 'VERB'),
#   (',', 'PUNCT'),
#   ('жиырма', 'NUM'),
#   ('бес', 'NUM'),
#   ('қамшы', 'NOUN'),
#   ('соқты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Копия', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('Қазақ', 'NOUN'),
#   ('тілі', 'NOUN'),
#   ('"', 'PUNCT'),
#   ('басқармасына', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Осы', 'PRON'),
#   ('жылдың', 'NOUN'),
#   ('15', 'NUM'),
#   ('қыркүйегінде', 'NOUN'),
#   ('миллионыншы', 'NUM'),
#   ('электронды', 'ADJ'),
#   ('құжат', 'NOUN'),
#   ('қабылданған', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Жалдамақ', 'VERB'),
#   ('кісісін', 'NOUN'),
#   ('бір', 'NUM'),
#   ('қаржы', 'NOUN'),
#   ('артық', 'ADV'),
#   ('беріп', 'VERB'),
#   (',', 'PUNCT'),
#   ('тартып', 'VERB'),
#   ('әкеткен', 'VERB'),
#   ('екен', 'AUX'),
#   ('.', 'PUNCT')],
#  [('–', 'PUNCT'),
#   ('Әркімге', 'PRON'),
#   ('жан', 'NOUN'),
#   ('керек', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Отырыс', 'NOUN'),
#   ('қорытындысы', 'NOUN'),
#   ('бойынша', 'ADP'),
#   ('Комиссия', 'PROPN'),
#   ('мемлекеттік', 'ADJ'),
#   ('органдарға', 'NOUN'),
#   ('нақты', 'ADJ'),
#   ('ұсынымдар', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('тапсырмалар', 'NOUN'),
#   ('берді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Мысырға', 'PROPN'),
#   ('адам', 'NOUN'),
#   ('осы', 'PRON'),
#   ('күні', 'NOUN'),
#   ('бірнеше', 'PRON'),
#   ('жұма', 'NOUN'),
#   ('жүріп', 'VERB'),
#   ('барса', 'VERB'),
#   (',', 'PUNCT'),
#   ('құс', 'NOUN'),
#   ('бірнеше', 'PRON'),
#   ('ғана', 'ADP'),
#   ('күнде', 'NOUN'),
#   ('жетеді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Өйткені', 'CONJ'),
#   ('мынау', 'PRON'),
#   ('арыздан', 'NOUN'),
#   ('өзі', 'PRON'),
#   ('де', 'ADP'),
#   ('шошынайын', 'VERB'),
#   ('деді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Тер', 'NOUN'), ('пұшпағынан', 'NOUN'), ('ақты', 'VERB'), ('.', 'PUNCT')],
#  [('Оқымыстылар', 'NOUN'),
#   ('айтуына', 'VERB'),
#   ('қарағанда', 'VERB'),
#   (',', 'PUNCT'),
#   ('көшпелі', 'ADJ'),
#   ('елдер', 'NOUN'),
#   ('ішінде', 'NOUN'),
#   ('қазақтың', 'NOUN'),
#   ('киіз', 'NOUN'),
#   ('үйіндей', 'ADJ'),
#   ('ыңғайлы', 'ADJ'),
#   (',', 'PUNCT'),
#   ('қолайлы', 'ADJ'),
#   (',', 'PUNCT'),
#   ('әдемі', 'ADJ'),
#   (',', 'PUNCT'),
#   ('жақсы', 'ADJ'),
#   ('үй', 'NOUN'),
#   ('жоқ', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Ұзақ', 'ADJ'),
#   ('түнгі', 'ADJ'),
#   ('топты', 'ADJ'),
#   ('қасқырмен', 'NOUN'),
#   ('арпалысқанын', 'VERB'),
#   ('заматта', 'NOUN'),
#   ('ұмытып', 'VERB'),
#   (',', 'PUNCT'),
#   ('шоңқайма', 'ADJ'),
#   ('кебісінің', 'NOUN'),
#   ('жез', 'ADJ'),
#   ('нәлі', 'NOUN'),
#   ('тастан', 'NOUN'),
#   ('тасқа', 'NOUN'),
#   ('шықылдап', 'VERB'),
#   (',', 'PUNCT'),
#   ('қашқан', 'VERB'),
#   ('киіктей', 'ADV'),
#   ('қаздаңдап', 'VERB'),
#   ('барады', 'AUX'),
#   ('ғой', 'ADP'),
#   ('!', 'PUNCT')],
#  [('Біз', 'PRON'),
#   ('Қазақстанның', 'PROPN'),
#   ('әлеуеті', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('болашағына', 'NOUN'),
#   ('сенеміз', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұдан', 'PRON'),
#   ('өзге', 'ADJ'),
#   (',', 'PUNCT'),
#   ('үкімде', 'NOUN'),
#   ('Матаевтардың', 'PROPN'),
#   ('жылжымайтын', 'VERB'),
#   ('мүліктері', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('пәтері', 'NOUN'),
#   (',', 'PUNCT'),
#   ('Ұлттық', 'ADJ'),
#   ('баспасөз', 'NOUN'),
#   ('клубы', 'NOUN'),
#   ('және', 'CONJ'),
#   ('көліктері', 'NOUN'),
#   ('тәркіленетіні', 'VERB'),
#   ('айтылды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Теміржол', 'NOUN'),
#   ('машиналарын', 'NOUN'),
#   ('жасау', 'VERB'),
#   ('саласы', 'NOUN'),
#   ('жаңадан', 'ADV'),
#   ('қалыптастырылды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('туралы', 'ADP'),
#   ('Өңірлік', 'ADJ'),
#   ('коммуникациялар', 'NOUN'),
#   ('қызметінде', 'NOUN'),
#   ('өткен', 'VERB'),
#   ('брифинг', 'NOUN'),
#   ('барысында', 'ADP'),
#   ('Жамбыл', 'PROPN'),
#   ('облысы', 'NOUN'),
#   ('әкімдігі', 'NOUN'),
#   ('білім', 'NOUN'),
#   ('басқарамасы', 'NOUN'),
#   ('басшысының', 'NOUN'),
#   ('орынбасары', 'NOUN'),
#   ('Бекбатырова', 'PROPN'),
#   ('Жәмилә', 'PROPN'),
#   ('Елеуқызы', 'PROPN'),
#   ('мәлімдеді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Әркім', 'PRON'),
#   ('өзінікін', 'PRON'),
#   ('жүптейді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('жаттығуға', 'NOUN'),
#   ('барлық', 'PRON'),
#   ('азаматтық', 'ADJ'),
#   ('қорғаныс', 'NOUN'),
#   ('ұйымдары', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('медицина', 'NOUN'),
#   (',', 'PUNCT'),
#   ('төтенше', 'ADJ'),
#   ('жағдай', 'NOUN'),
#   ('жөніндегі', 'ADP'),
#   ('мекемелер', 'NOUN'),
#   ('және', 'CONJ'),
#   ('оқу', 'NOUN'),
#   ('орындары', 'NOUN'),
#   ('қатысады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Амал', 'NOUN'),
#   ('жоқ', 'ADJ'),
#   (',', 'PUNCT'),
#   ('бүрсеңдеп', 'VERB'),
#   ('жүріп', 'VERB'),
#   ('қозы', 'NOUN'),
#   ('ағытып', 'VERB'),
#   (',', 'PUNCT'),
#   ('бір', 'NUM'),
#   ('тостаған', 'NOUN'),
#   ('іркіт', 'NOUN'),
#   ('ішіп', 'VERB'),
#   (',', 'PUNCT'),
#   ('көзіңді', 'NOUN'),
#   ('уқалап', 'VERB'),
#   ('жөнелесің', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Салған', 'VERB'),
#   ('жерден', 'NOUN'),
#   ('бір', 'PRON'),
#   ('қолын', 'NOUN'),
#   ('Нығман', 'PROPN'),
#   ('ұстап', 'VERB'),
#   ('алып', 'AUX'),
#   (',', 'PUNCT'),
#   ('босатпай', 'VERB'),
#   ('қойды', 'AUX'),
#   ('.', 'PUNCT')],
#  [('М.', 'PROPN'),
#   ('Пішембаев', 'PROPN'),
#   (':', 'PUNCT'),
#   ('Қазақстанда', 'PROPN'),
#   ('австриялық', 'ADJ'),
#   ('капиталдың', 'NOUN'),
#   ('қатысуымен', 'VERB'),
#   ('140', 'NUM'),
#   ('астам', 'ADP'),
#   ('кәсіпорын', 'NOUN'),
#   ('жұмыс', 'NOUN'),
#   ('істейді', 'VERB')],
#  [('Журналистер', 'NOUN'),
#   ('С.', 'PROPN'),
#   ('Матаевқа', 'PROPN'),
#   ('сенім', 'NOUN'),
#   ('білдірді', 'VERB')],
#  [('Мемлекет', 'PROPN'),
#   ('басшысының', 'NOUN'),
#   ('тапсырмасымен', 'NOUN'),
#   ('Жер', 'NOUN'),
#   ('реформасы', 'NOUN'),
#   ('бойынша', 'ADP'),
#   ('комиссия', 'NOUN'),
#   ('құрылды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ұлттық', 'ADJ'),
#   ('банк', 'NOUN'),
#   ('мұны', 'PRON'),
#   ('басты', 'ADJ'),
#   ('экспорттық', 'ADJ'),
#   ('өніміміз', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('көмірсутек', 'NOUN'),
#   ('бағасының', 'NOUN'),
#   ('құлдырауымен', 'VERB'),
#   ('түсіндіреді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Сенат', 'PROPN'),
#   ('депутаты', 'NOUN'),
#   ('болып', 'VERB'),
#   ('сайлану', 'VERB'),
#   ('үшін', 'ADP'),
#   ('азамат', 'NOUN'),
#   ('Конституцияның', 'PROPN'),
#   ('51', 'NUM'),
#   ('-', 'PUNCT'),
#   ('бабының', 'NOUN'),
#   ('4', 'NUM'),
#   ('-', 'PUNCT'),
#   ('тармағында', 'NOUN'),
#   ('белгіленген', 'VERB'),
#   ('талаптарды', 'NOUN'),
#   ('қанағаттандыруға', 'VERB'),
#   (',', 'PUNCT'),
#   ('сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   ('Конституцияның', 'PROPN'),
#   ('33', 'NUM'),
#   ('-', 'PUNCT'),
#   ('бабының', 'NOUN'),
#   ('2', 'NUM'),
#   ('және', 'CONJ'),
#   ('3', 'NUM'),
#   ('-', 'PUNCT'),
#   ('тармақтарына', 'NOUN'),
#   ('және', 'CONJ'),
#   ('осы', 'PRON'),
#   ('Конституциялық', 'ADJ'),
#   ('заңға', 'NOUN'),
#   ('сәйкес', 'ADP'),
#   ('белсенді', 'ADJ'),
#   ('сайлау', 'NOUN'),
#   ('құқығына', 'NOUN'),
#   ('ие', 'NOUN'),
#   ('болуға', 'VERB'),
#   ('тиіс', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Қайта', 'ADV'),
#   ('сайлауда', 'VERB'),
#   ('жүзеге', 'NOUN'),
#   ('асыру', 'VERB'),
#   ('көзделген', 'VERB'),
#   ('сайлау', 'NOUN'),
#   ('шаралары', 'NOUN'),
#   ('осы', 'PRON'),
#   ('Конституциялық', 'ADJ'),
#   ('заңда', 'NOUN'),
#   ('белгіленген', 'VERB'),
#   ('ережелерге', 'NOUN'),
#   ('сәйкес', 'ADV'),
#   ('жүргізіледі', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Әлде', 'SCONJ'),
#   ('Ресеймен', 'PROPN'),
#   ('қарым-қатынасты', 'NOUN'),
#   ('суытып', 'VERB'),
#   ('аламын', 'AUX'),
#   ('деп', 'VERB'),
#   ('сескенді', 'VERB'),
#   ('ме', 'PART'),
#   ('?', 'PUNCT')],
#  [('Орысша', 'ADJ'),
#   ('тілді', 'NOUN'),
#   ('де', 'ADP'),
#   ('біліпті', 'VERB'),
#   (',', 'PUNCT'),
#   ('көшеде', 'NOUN'),
#   ('өтіп', 'VERB'),
#   ('бара', 'AUX'),
#   ('жатқан', 'AUX'),
#   ('орыстарға', 'NOUN'),
#   ('қалпағын', 'NOUN'),
#   ('алып', 'VERB'),
#   ('«', 'PUNCT'),
#   ('іздірәсти', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('амандасып', 'VERB'),
#   ('жүр', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Сушыл', 'ADJ'),
#   ('құстардың', 'NOUN'),
#   ('адам', 'NOUN'),
#   ('бәрінің', 'PRON'),
#   ('де', 'ADP'),
#   ('жұмыртқасын', 'NOUN'),
#   ('жейді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Кездесу', 'NOUN'),
#   ('барысында', 'ADP'),
#   ('Қазақ', 'PROPN'),
#   ('хандығының', 'NOUN'),
#   ('550', 'NUM'),
#   ('жылдығын', 'NOUN'),
#   ('мерекелеуге', 'VERB'),
#   ('дайындық', 'NOUN'),
#   ('мәселелері', 'NOUN'),
#   (',', 'PUNCT'),
#   ('сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   ('«', 'PUNCT'),
#   ('100', 'NUM'),
#   ('нақты', 'ADJ'),
#   ('қадам', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('ұлттық', 'ADJ'),
#   ('іс-қимыл', 'NOUN'),
#   ('жоспарын', 'NOUN'),
#   ('жүзеге', 'NOUN'),
#   ('асыру', 'VERB'),
#   ('аясындағы', 'ADJ'),
#   ('министрліктің', 'NOUN'),
#   ('қызметі', 'NOUN'),
#   ('талқыланды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Америкенің', 'PROPN'),
#   ('(', 'PUNCT'),
#   ('Америка', 'PROPN'),
#   (')', 'PUNCT'),
#   ('темірқазығынан', 'NOUN'),
#   ('оңтүстігіне', 'NOUN'),
#   ('әлденеше', 'PRON'),
#   ('мың', 'NUM'),
#   ('шақырым', 'NOUN'),
#   ('жерге', 'NOUN'),
#   (',', 'PUNCT'),
#   ('жаяу', 'ADV'),
#   ('ауып', 'VERB'),
#   ('келген', 'AUX'),
#   ('аңшы', 'NOUN'),
#   ('индейтстерді', 'NOUN'),
#   ('(', 'PUNCT'),
#   ('индеец', 'NOUN'),
#   (')', 'PUNCT'),
#   ('жолаушылар', 'NOUN'),
#   ('көрдік', 'VERB'),
#   ('деседі', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Атшы', 'NOUN'),
#   ('көкек', 'NOUN'),
#   ('ағаш', 'NOUN'),
#   ('қуысына', 'NOUN'),
#   ('ұялайды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Матаевты', 'PROPN'),
#   ('қамау', 'VERB'),
#   ('мерзімі', 'NOUN'),
#   ('ұзартылды', 'VERB')],
#  [('Бесеуі', 'NUM'),
#   ('де', 'ADP'),
#   ('Меккеге', 'PROPN'),
#   ('жерленеді', 'VERB')],
#  [('Бесігімен', 'NOUN'),
#   ('домалап', 'VERB'),
#   ('жас', 'ADJ'),
#   ('бала', 'NOUN'),
#   ('тұншытып', 'VERB'),
#   ('жатыр', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Қазіргі', 'ADJ'),
#   ('уақытта', 'NOUN'),
#   ('танысу', 'NOUN'),
#   ('қалыпты', 'ADJ'),
#   ('уақытта', 'NOUN'),
#   ('өтіп', 'VERB'),
#   ('жатыр', 'AUX'),
#   (',', 'PUNCT'),
#   ('бірақ', 'SCONJ'),
#   ('оның', 'PRON'),
#   ('қанша', 'PRON'),
#   ('уақытқа', 'NOUN'),
#   ('созылатынын', 'VERB'),
#   ('болжай', 'VERB'),
#   ('алмаймын', 'AUX'),
#   ('”', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('депті', 'VERB'),
#   ('Исаев', 'PROPN'),
#   ('.', 'PUNCT')],
#  [('–', 'PUNCT'),
#   ('Өңірдің', 'NOUN'),
#   ('дамуына', 'NOUN'),
#   ('соңғы', 'ADJ'),
#   ('жылдары', 'NOUN'),
#   ('500', 'NUM'),
#   ('миллиард', 'NUM'),
#   ('теңгеден', 'NOUN'),
#   ('астам', 'ADP'),
#   ('қаражат', 'NOUN'),
#   ('жұмсалды', 'VERB'),
#   (',', 'PUNCT'),
#   ('500', 'NUM'),
#   ('мың', 'NUM'),
#   ('шаршы', 'NOUN'),
#   ('метр', 'NOUN'),
#   ('баспана', 'NOUN'),
#   ('пайдалануға', 'VERB'),
#   ('беріліп', 'VERB'),
#   (',', 'PUNCT'),
#   ('бес', 'NUM'),
#   ('мектеп', 'NOUN'),
#   (',', 'PUNCT'),
#   ('2', 'NUM'),
#   ('балабақша', 'NOUN'),
#   ('салынды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('О', 'PRON'),
#   ('кезде', 'NOUN'),
#   ('ызғырығы', 'NOUN'),
#   ('ызылдап', 'VERB'),
#   (',', 'PUNCT'),
#   ('бойды', 'NOUN'),
#   ('мұздатып', 'VERB'),
#   (',', 'PUNCT'),
#   ('сабалақ', 'ADJ'),
#   ('қара', 'ADJ'),
#   ('бұлттан', 'NOUN'),
#   ('түн', 'NOUN'),
#   ('жамылған', 'VERB'),
#   ('күздің', 'NOUN'),
#   ('көзсіз', 'ADJ'),
#   ('қара', 'ADJ'),
#   ('түні', 'NOUN'),
#   ('ақ', 'ADJ'),
#   ('бас', 'NOUN'),
#   ('Алтайдың', 'PROPN'),
#   ('үстіне', 'NOUN'),
#   ('қара', 'ADJ'),
#   ('бурадай', 'NOUN'),
#   ('шөгіп', 'VERB'),
#   (',', 'PUNCT'),
#   ('сай', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('салаға', 'NOUN'),
#   ('бауырын', 'NOUN'),
#   ('төсеп', 'VERB'),
#   (',', 'PUNCT'),
#   ('дүние', 'NOUN'),
#   ('қарауытып', 'VERB'),
#   ('келе', 'AUX'),
#   ('жатыр', 'AUX'),
#   ('еді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Нұрсұлтан', 'PROPN'),
#   ('Назарбаев', 'PROPN'),
#   ('елорданың', 'NOUN'),
#   ('Оқушылар', 'NOUN'),
#   ('сарайында', 'NOUN'),
#   ('орналасқан', 'VERB'),
#   ('сайлау', 'NOUN'),
#   ('учаскесіне', 'NOUN'),
#   ('келіп', 'VERB'),
#   (',', 'PUNCT'),
#   ('Қазақстан', 'PROPN'),
#   ('Республикасы', 'PROPN'),
#   ('Президентінің', 'PROPN'),
#   ('сайлауында', 'NOUN'),
#   ('дауыс', 'NOUN'),
#   ('берді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Астындағысы', 'NOUN'),
#   ('тойып', 'VERB'),
#   ('тұрған', 'AUX'),
#   ('ат', 'NOUN'),
#   ('екен', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Алыстан', 'ADV'),
#   ('жақындағаннан', 'VERB'),
#   ('-ақ', 'ADP'),
#   (',', 'PUNCT'),
#   ('аңшылар', 'NOUN'),
#   ('шат', 'ADJ'),
#   ('болып', 'VERB'),
#   ('қайтқанын', 'VERB'),
#   ('білдіріп', 'VERB'),
#   (',', 'PUNCT'),
#   ('секіріп', 'VERB'),
#   (',', 'PUNCT'),
#   ('дауыстап', 'VERB'),
#   (',', 'PUNCT'),
#   ('қуаныш', 'NOUN'),
#   ('белгісін', 'NOUN'),
#   ('білдіре', 'VERB'),
#   ('бастады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Оның', 'PRON'),
#   ('құрамына', 'NOUN'),
#   ('ҚР', 'PROPN'),
#   ('Денсаулық', 'NOUN'),
#   ('сақтау', 'VERB'),
#   ('министрлігінің', 'NOUN'),
#   (',', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('Атамекен', 'PROPN'),
#   ('»', 'PUNCT'),
#   ('ҰКП', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('жеке', 'ADJ'),
#   ('меншік', 'NOUN'),
#   ('медициналық', 'ADJ'),
#   ('мекемелердің', 'NOUN'),
#   ('өкілдері', 'NOUN'),
#   ('кірген', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ондағы', 'ADJ'),
#   ('ойы', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('қонақ', 'NOUN'),
#   ('үйде', 'NOUN'),
#   ('тілмәш', 'NOUN'),
#   ('болса', 'VERB'),
#   (',', 'PUNCT'),
#   ('соған', 'PRON'),
#   ('жолығу', 'VERB'),
#   ('еді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Мұндай', 'ADJ'),
#   ('да', 'ADP'),
#   ('жауыздық', 'NOUN'),
#   ('болады', 'VERB'),
#   ('екен', 'AUX'),
#   ('!', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('тұра', 'VERB'),
#   ('жөнелді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Баян', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('екі', 'NUM'),
#   ('ара', 'NOUN'),
#   ('ағыл-тегіл', 'ADV'),
#   ('жүріп', 'VERB'),
#   ('жатқан', 'AUX'),
#   ('атқа', 'NOUN'),
#   (',', 'PUNCT'),
#   ('түйеге', 'NOUN'),
#   ('салған', 'VERB'),
#   ('көлік', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Тақымына', 'NOUN'),
#   ('қыстырған', 'VERB'),
#   ('«', 'PUNCT'),
#   ('бір', 'PRON'),
#   ('салар', 'VERB'),
#   ('»', 'PUNCT'),
#   ('шоқпары', 'NOUN'),
#   (',', 'PUNCT'),
#   ('тақыммен', 'NOUN'),
#   ('ойнаған', 'VERB'),
#   ('есік', 'NOUN'),
#   ('пен', 'CONJ'),
#   ('төрдей', 'ADJ'),
#   ('боз', 'ADJ'),
#   ('аты', 'NOUN'),
#   (',', 'PUNCT'),
#   ('басында', 'NOUN'),
#   ('жас', 'ADJ'),
#   ('баланың', 'NOUN'),
#   ('үкі', 'NOUN'),
#   ('таққан', 'VERB'),
#   ('жекей', 'NOUN'),
#   ('тымағы', 'NOUN'),
#   ('бар', 'ADJ'),
#   (',', 'PUNCT'),
#   ('мойны', 'NOUN'),
#   ('сорайған', 'VERB'),
#   ('бір', 'PRON'),
#   ('жігіт', 'NOUN'),
#   ('Қартқожаның', 'PROPN'),
#   ('қасынан', 'NOUN'),
#   ('сыдыртып', 'VERB'),
#   ('өте', 'VERB'),
#   ('шықты', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Осы', 'DET'),
#   ('жылы', 'NOUN'),
#   ('байқауға', 'NOUN'),
#   ('қатысушылардың', 'NOUN'),
#   ('таланттарын', 'NOUN'),
#   ('Қазақстан', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Ресей', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Беларусь', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Италия', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Израиль', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Германия', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('Қытайдың', 'PROPN'),
#   ('аты', 'NOUN'),
#   ('әлемге', 'NOUN'),
#   ('әйгілі', 'ADJ'),
#   ('әртістері', 'NOUN'),
#   (',', 'PUNCT'),
#   ('профессорлар', 'NOUN'),
#   (',', 'PUNCT'),
#   ('шығармашыл', 'ADJ'),
#   ('элита', 'NOUN'),
#   ('өкілдері', 'NOUN'),
#   ('бағалайтын', 'VERB'),
#   ('болады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Мемлекет', 'PROPN'),
#   ('басшысына', 'NOUN'),
#   ('Қазақстанның', 'PROPN'),
#   ('тарихи', 'ADJ'),
#   ('және', 'CONJ'),
#   ('мәдени', 'ADJ'),
#   ('мұрасын', 'NOUN'),
#   ('саралап', 'VERB'),
#   (',', 'PUNCT'),
#   ('баға', 'NOUN'),
#   ('беретін', 'VERB'),
#   ('заманауи', 'ADJ'),
#   ('интеллектуалдық', 'ADJ'),
#   ('орталық', 'NOUN'),
#   ('болуды', 'VERB'),
#   ('көздеп', 'VERB'),
#   ('отырған', 'AUX'),
#   ('музейдің', 'NOUN'),
#   ('қызметі', 'NOUN'),
#   ('туралы', 'ADP'),
#   ('баяндалды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('сұрау', 'NOUN'),
#   ('Мұқашқа', 'PROPN'),
#   ('шәлкем', 'ADV'),
#   ('-', 'PUNCT'),
#   ('шалыс', 'ADV'),
#   ('келді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Әлде', 'CONJ'),
#   ('құдайға', 'NOUN'),
#   ('тапсырып', 'VERB'),
#   ('кетіп', 'VERB'),
#   ('қалам', 'AUX'),
#   ('ба', 'PART'),
#   ('?', 'PUNCT')],
#  [('Не', 'PRON'),
#   ('де', 'ADP'),
#   ('болса', 'VERB'),
#   ('үйге', 'NOUN'),
#   ('кіру', 'VERB'),
#   ('керек', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Қанайға', 'PROPN'),
#   ('бес', 'NUM'),
#   ('шақырым', 'NOUN'),
#   ('қалғанда', 'VERB'),
#   (',', 'PUNCT'),
#   ('шеткі', 'ADJ'),
#   ('адырды', 'NOUN'),
#   ('бетке', 'NOUN'),
#   ('ұстап', 'VERB'),
#   (',', 'PUNCT'),
#   ('жасақ', 'NOUN'),
#   ('тоқтады', 'VERB'),
#   (',', 'PUNCT'),
#   ('ұйлықты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Жеңешем', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('ағатайымды', 'NOUN'),
#   ('қимай', 'VERB'),
#   ('көп', 'ADV'),
#   ('жыладым', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Швейцарияның', 'PROPN'),
#   ('Астанада', 'PROPN'),
#   ('өтетін', 'VERB'),
#   ('«', 'PUNCT'),
#   ('ЭКСПО-2017', 'PROPN'),
#   ('»', 'PUNCT'),
#   ('көрмесіне', 'NOUN'),
#   ('қатысуы', 'VERB'),
#   ('серіктестігіміздің', 'NOUN'),
#   ('аясын', 'NOUN'),
#   ('кеңейте', 'VERB'),
#   ('түсуге', 'AUX'),
#   ('тамаша', 'ADJ'),
#   ('мүмкіндік', 'NOUN'),
#   ('тудырады', 'VERB'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('делінген', 'VERB'),
#   ('жеделхатта', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('"', 'PUNCT'),
#   ('Не', 'PRON'),
#   ('бетіммен', 'NOUN'),
#   ('барам', 'VERB'),
#   ('"', 'PUNCT'),
#   ('деген', 'VERB'),
#   ('ой', 'NOUN'),
#   ('келді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Дүниежүзілік', 'ADJ'),
#   ('экономикалық', 'ADJ'),
#   ('форумның', 'NOUN'),
#   ('2014', 'NUM'),
#   ('жылғы', 'ADJ'),
#   ('есебіне', 'NOUN'),
#   ('сәйкес', 'ADP'),
#   ('57', 'NUM'),
#   ('елден', 'NOUN'),
#   ('тұратын', 'VERB'),
#   ('топта', 'NOUN'),
#   ('елде', 'NOUN'),
#   ('АИТВ', 'PROPN'),
#   ('инфекциясының', 'NOUN'),
#   ('таралуы', 'VERB'),
#   ('бойынша', 'ADP'),
#   ('Қазақстан', 'PROPN'),
#   ('төмен', 'ADJ'),
#   ('көрсеткіш', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('0,2', 'NUM'),
#   ('пайызбен', 'NOUN'),
#   ('бірінші', 'NUM'),
#   ('орынға', 'NOUN'),
#   ('тұрақтады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Инвестициялар', 'NOUN'),
#   ('және', 'CONJ'),
#   ('даму', 'NOUN'),
#   ('министрлігі', 'NOUN'),
#   ('геология', 'NOUN'),
#   ('және', 'CONJ'),
#   ('жер', 'NOUN'),
#   ('қойнауын', 'NOUN'),
#   ('пайдалану', 'VERB'),
#   ('комитетінің', 'NOUN'),
#   ('төрағасы', 'NOUN'),
#   ('Базарбай', 'PROPN'),
#   ('Нұрабаев', 'PROPN'),
#   ('2016', 'NUM'),
#   ('жылы', 'NOUN'),
#   ('атқарылған', 'VERB'),
#   ('жұмыстардың', 'NOUN'),
#   ('негізгі', 'ADJ'),
#   ('қорытындылары', 'NOUN'),
#   (',', 'PUNCT'),
#   ('сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   ('Қазақстан', 'PROPN'),
#   ('Тәуелсіздігінің', 'PROPN'),
#   ('25', 'NUM'),
#   ('жылы', 'NOUN'),
#   ('ішінде', 'NOUN'),
#   ('қол', 'NOUN'),
#   ('жеткізілген', 'VERB'),
#   ('нәтижелер', 'NOUN'),
#   ('жөнінде', 'ADP'),
#   ('баяндады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Міне', 'PRON'),
#   (',', 'PUNCT'),
#   ('тұрмыстың', 'NOUN'),
#   ('түрлі', 'ADJ'),
#   ('тарауларының', 'NOUN'),
#   ('бірімен-бірінің', 'PRON'),
#   ('ілгешектігі', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Жақын', 'ADJ'),
#   ('күндері', 'NOUN'),
#   ('бұл', 'PRON'),
#   ('ескерткіш', 'NOUN'),
#   ('қаланың', 'NOUN'),
#   ('орталығына', 'NOUN'),
#   ('қойылады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ғали', 'PROPN'),
#   ('Жамалмен', 'PROPN'),
#   ('қатар', 'ADV'),
#   ('отырған', 'VERB'),
#   ('соң', 'ADP'),
#   (',', 'PUNCT'),
#   ('бір', 'PRON'),
#   ('-', 'PUNCT'),
#   ('бірінің', 'PRON'),
#   ('халін', 'NOUN'),
#   ('һәм', 'CONJ'),
#   ('кім', 'PRON'),
#   ('екендіктерін', 'VERB'),
#   ('сұрап', 'VERB'),
#   ('білісті', 'AUX'),
#   ('.', 'PUNCT')],
#  [('–', 'PUNCT'),
#   ('Сіздің', 'PRON'),
#   ('де', 'ADP'),
#   ('ауыл', 'NOUN'),
#   ('аман', 'ADV'),
#   (',', 'PUNCT'),
#   ('сіздің', 'PRON'),
#   ('ауыл', 'NOUN'),
#   ('да', 'ADP'),
#   ('аман', 'ADV'),
#   ('.', 'PUNCT'),
#   ('.', 'PUNCT'),
#   ('.', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('бәрін', 'PRON'),
#   ('кәні', 'NOUN'),
#   ('қылды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Бәйбіше', 'NOUN'),
#   ('—', 'PUNCT'),
#   ('тоқалды', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('ойнағанда', 'VERB'),
#   ('мен', 'PRON'),
#   ('Мәмеш', 'PROPN'),
#   ('болдым', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Сенің', 'PRON'),
#   ('тұқымыңа', 'NOUN'),
#   ('ірілік', 'NOUN'),
#   (',', 'PUNCT'),
#   ('паңдық', 'NOUN'),
#   ('жаққан', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Біз', 'PRON'),
#   ('заманауи', 'ADJ'),
#   ('технологиялар', 'NOUN'),
#   ('енгізіліп', 'VERB'),
#   ('жатқанын', 'AUX'),
#   ('көріп', 'VERB'),
#   ('отырмыз', 'AUX'),
#   (',', 'PUNCT'),
#   ('соның', 'PRON'),
#   ('есебінен', 'NOUN'),
#   ('өндіріс', 'NOUN'),
#   ('ұлғаюда', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ойын-сауыққа', 'NOUN'),
#   ('белсеніп', 'VERB'),
#   ('кірісе', 'VERB'),
#   ('алмайды', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Кәсіпорын', 'NOUN'),
#   ('арнаулы', 'ADJ'),
#   ('техника', 'NOUN'),
#   (',', 'PUNCT'),
#   ('мұнай-газ', 'NOUN'),
#   ('саласы', 'NOUN'),
#   ('үшін', 'ADP'),
#   ('жабдықталған', 'VERB'),
#   ('катер', 'NOUN'),
#   ('және', 'CONJ'),
#   ('кемелер', 'NOUN'),
#   ('сияқты', 'ADP'),
#   ('өнімдер', 'NOUN'),
#   ('шығарады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бүгінгі', 'ADJ'),
#   ('таңда', 'NOUN'),
#   ('біздің', 'PRON'),
#   ('жұмысымыздың', 'NOUN'),
#   ('нәтижесінде', 'NOUN'),
#   ('«', 'PUNCT'),
#   ('ЭКСПО-2017', 'PROPN'),
#   ('»', 'PUNCT'),
#   ('көрмесіне', 'NOUN'),
#   ('112', 'NUM'),
#   ('мемлекет', 'NOUN'),
#   ('пен', 'CONJ'),
#   ('18', 'NUM'),
#   ('халықаралық', 'ADJ'),
#   ('ұйымның', 'NOUN'),
#   ('қатысатыны', 'VERB'),
#   ('расталды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Қазақстан', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('БҰҰ', 'PROPN'),
#   ('көптеген', 'ADJ'),
#   ('салаларда', 'NOUN'),
#   ('тығыз', 'ADJ'),
#   ('әрі', 'CONJ'),
#   ('жан-жақты', 'ADJ'),
#   ('қарым-қатынас', 'NOUN'),
#   ('орнатты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Қазақстан', 'PROPN'),
#   ('Президентінің', 'PROPN'),
#   ('шешіміне', 'NOUN'),
#   ('сәйкес', 'ADP'),
#   ('2013', 'NUM'),
#   ('жылы', 'NOUN'),
#   ('ашылған', 'VERB'),
#   ('бұл', 'PRON'),
#   ('көпфункционалды', 'ADJ'),
#   ('зал', 'NOUN'),
#   ('бүгінде', 'ADV'),
#   ('БҰҰ-ның', 'PROPN'),
#   ('Женевадағы', 'PROPN'),
#   ('штаб-пәтеріндегі', 'ADJ'),
#   ('техникалық', 'ADJ'),
#   ('жағынан', 'NOUN'),
#   ('барынша', 'ADV'),
#   ('жабдықталған', 'VERB'),
#   ('орынжай', 'NOUN'),
#   ('болып', 'VERB'),
#   ('саналады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Міне', 'INTJ'),
#   (',', 'PUNCT'),
#   ('бұған', 'PRON'),
#   ('түрлі', 'ADJ'),
#   ('себеп', 'NOUN'),
#   ('бар', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Екі', 'NUM'),
#   ('ел', 'NOUN'),
#   ('президенттері', 'NOUN'),
#   ('сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'CONJ'),
#   ('Қазақстан', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('Грузияның', 'PROPN'),
#   ('өзара', 'ADJ'),
#   ('ықпалдастығын', 'NOUN'),
#   ('арттыру', 'VERB'),
#   ('мәселелерін', 'NOUN'),
#   ('талқылады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Су', 'NOUN'),
#   ('түбіндегі', 'ADJ'),
#   ('жемін', 'NOUN'),
#   ('алып', 'VERB'),
#   ('жеуге', 'VERB'),
#   ('қайым', 'ADJ'),
#   ('біткен', 'VERB'),
#   ('тұмсықтары', 'NOUN'),
#   ('да', 'ADP'),
#   ('ұзын', 'ADJ'),
#   ('болады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('кісі', 'NOUN'),
#   ('сені', 'PRON'),
#   ('жақсы', 'ADV'),
#   ('көреді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұқаралық', 'ADJ'),
#   ('ақпарат', 'NOUN'),
#   ('құралдарының', 'NOUN'),
#   ('лауазымды', 'ADJ'),
#   ('адамдары', 'NOUN'),
#   (',', 'PUNCT'),
#   ('осы', 'PRON'),
#   ('Конституциялық', 'ADJ'),
#   ('заңның', 'NOUN'),
#   ('29', 'NUM'),
#   ('-', 'PUNCT'),
#   ('бабының', 'NOUN'),
#   ('1', 'NUM'),
#   ('-', 'PUNCT'),
#   ('тармағында', 'NOUN'),
#   ('көрсетілген', 'VERB'),
#   ('материалдарды', 'NOUN'),
#   ('жариялау', 'VERB'),
#   ('жағдайларын', 'NOUN'),
#   ('қоспағанда', 'VERB'),
#   (',', 'PUNCT'),
#   ('кандидаттар', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('саяси', 'ADJ'),
#   ('партиялардың', 'NOUN'),
#   ('сайлау', 'NOUN'),
#   ('алдындағы', 'ADJ'),
#   ('науқан', 'NOUN'),
#   ('барысында', 'NOUN'),
#   ('айтқан', 'VERB'),
#   ('пікірлері', 'NOUN'),
#   ('үшін', 'ADP'),
#   ('жауапты', 'ADJ'),
#   ('болмайды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Қазақстан', 'PROPN'),
#   ('Президенті', 'PROPN'),
#   ('Нұрсұлтан', 'PROPN'),
#   ('Назарбаев', 'PROPN'),
#   ('Жер', 'NOUN'),
#   ('реформасы', 'NOUN'),
#   ('жөніндегі', 'ADP'),
#   ('комиссия', 'NOUN'),
#   ('мүшелеріне', 'NOUN'),
#   ('тиісті', 'ADJ'),
#   ('заңнаманы', 'NOUN'),
#   ('жетілдіру', 'VERB'),
#   ('бойынша', 'ADP'),
#   ('келісілген', 'VERB'),
#   ('ұстаным', 'NOUN'),
#   ('әзірлеуді', 'VERB'),
#   ('тапсырды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Үш', 'NUM'),
#   ('ер', 'NOUN'),
#   ('адам', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('әйел', 'NOUN'),
#   ('және', 'CONJ'),
#   ('2014', 'NUM'),
#   ('жылы', 'NOUN'),
#   ('туған', 'VERB'),
#   ('бала', 'NOUN'),
#   ('оқиға', 'NOUN'),
#   ('орнында', 'NOUN'),
#   ('жан', 'NOUN'),
#   ('тапсырды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Қалыңмалдың', 'NOUN'),
#   ('бір', 'NUM'),
#   ('қарасы', 'NOUN'),
#   ('—', 'PUNCT'),
#   ('байдың', 'NOUN'),
#   ('сыбағасы', 'NOUN'),
#   ('болады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Мемлекет', 'PROPN'),
#   ('басшысы', 'NOUN'),
#   ('ТМД', 'PROPN'),
#   ('елдері', 'NOUN'),
#   ('прокуратураларының', 'NOUN'),
#   ('өзара', 'ADJ'),
#   ('іс-қимылын', 'NOUN'),
#   ('күшейтудің', 'VERB'),
#   ('қажеттігін', 'NOUN'),
#   ('атап', 'VERB'),
#   ('айтты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Темірден', 'NOUN'),
#   ('құрал', 'NOUN'),
#   ('жасау', 'VERB'),
#   ('түгіл', 'ADP'),
#   (',', 'PUNCT'),
#   ('жер', 'NOUN'),
#   ('үстінде', 'NOUN'),
#   ('темір', 'NOUN'),
#   ('барын', 'ADJ'),
#   ('да', 'ADP'),
#   ('білмейді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Дәрмен', 'PROPN'),
#   ('жауырынынан', 'NOUN'),
#   ('ұстап', 'VERB'),
#   (',', 'PUNCT'),
#   ('«', 'PUNCT'),
#   ('әуіп', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('деп', 'VERB'),
#   (',', 'PUNCT'),
#   ('өзіне', 'PRON'),
#   ('таман', 'ADP'),
#   ('тартып', 'VERB'),
#   ('алды', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Ұсталған', 'VERB'),
#   ('кәсіпкерлердің', 'NOUN'),
#   ('саны', 'NOUN'),
#   ('20-ға', 'NUM'),
#   ('жетеді', 'VERB'),
#   ('Түркіменстанда', 'PROPN'),
#   ('соңғы', 'ADJ'),
#   ('күндері', 'NOUN'),
#   ('бірқатар', 'PRON'),
#   ('ірі', 'ADJ'),
#   ('кәсіпкерлер', 'NOUN'),
#   ('ұсталды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Патрик', 'PROPN'),
#   ('Пуянне', 'PROPN'),
#   ('өз', 'PRON'),
#   ('сөзінде', 'NOUN'),
#   ('Нұрсұлтан', 'PROPN'),
#   ('Назарбаевқа', 'PROPN'),
#   ('Қашаған', 'PROPN'),
#   ('кенішін', 'NOUN'),
#   ('игеру', 'VERB'),
#   ('және', 'CONJ'),
#   ('еліміздегі', 'ADJ'),
#   ('өзге', 'ADJ'),
#   ('де', 'ADP'),
#   ('инвестициялық', 'ADJ'),
#   ('жобалардың', 'NOUN'),
#   ('жүзеге', 'NOUN'),
#   ('асырылу', 'VERB'),
#   ('барысы', 'NOUN'),
#   ('туралы', 'ADP'),
#   ('айтты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бірақ', 'CONJ'),
#   ('Бекболат', 'PROPN'),
#   ('салған', 'VERB'),
#   ('жерден', 'NOUN'),
#   ('Ақбілектен', 'PROPN'),
#   ('бастауды', 'VERB'),
#   ('қолайсыз', 'ADV'),
#   ('көріп', 'VERB'),
#   (',', 'PUNCT'),
#   ('құс', 'NOUN'),
#   ('жайынан', 'NOUN'),
#   ('қозғағаны', 'VERB'),
#   ('соның', 'PRON'),
#   ('беташары', 'NOUN'),
#   ('еді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Мысықпен', 'NOUN'),
#   ('тұқымдас', 'ADJ'),
#   ('толып', 'VERB'),
#   ('жатқан', 'AUX'),
#   ('аңдар', 'NOUN'),
#   ('бар', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Саяси', 'ADJ'),
#   ('партиялардан', 'NOUN'),
#   ('Парламент', 'PROPN'),
#   ('Мәжілісінің', 'PROPN'),
#   ('депутаттары', 'NOUN'),
#   ('біртұтас', 'ADJ'),
#   ('жалпыұлттық', 'ADJ'),
#   ('сайлау', 'NOUN'),
#   ('округі', 'NOUN'),
#   ('бойынша', 'ADP'),
#   ('партиялық', 'ADJ'),
#   ('тізімдермен', 'NOUN'),
#   ('сайланады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Мемлекеттік', 'ADJ'),
#   ('емес', 'VERB'),
#   ('сектордың', 'NOUN'),
#   ('үлес', 'NOUN'),
#   ('төмен', 'ADJ'),
#   (':', 'PUNCT'),
#   ('небәрі', 'ADV'),
#   ('27,2', 'NUM'),
#   ('%', 'SYM'),
#   (',', 'PUNCT'),
#   ('бұл', 'PRON'),
#   ('1102', 'NUM'),
#   ('медициналық', 'ADJ'),
#   ('мекеме', 'NOUN'),
#   (',', 'PUNCT'),
#   ('олардың', 'PRON'),
#   ('941', 'NUM'),
#   ('амбулаториялық', 'ADJ'),
#   ('емхана', 'NOUN'),
#   ('мекемесі', 'NOUN'),
#   ('(', 'PUNCT'),
#   ('85,3', 'NUM'),
#   ('%', 'SYM'),
#   (')', 'PUNCT'),
#   ('және', 'CONJ'),
#   ('161', 'NUM'),
#   ('аурухана', 'NOUN'),
#   ('(', 'PUNCT'),
#   ('14,6', 'NUM'),
#   ('%', 'SYM'),
#   (')', 'PUNCT'),
#   ('.', 'PUNCT')],
#  [('Шешінбестен', 'VERB'),
#   ('төсекке', 'NOUN'),
#   ('келіп', 'VERB'),
#   ('қылжиып', 'VERB'),
#   (',', 'PUNCT'),
#   ('әлгі', 'ADJ'),
#   ('төбелескен', 'VERB'),
#   ('жігітті', 'NOUN'),
#   ('боқтап', 'VERB'),
#   ('жатып', 'AUX'),
#   ('ұйықтап', 'VERB'),
#   ('қалды', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Өзге', 'ADJ'),
#   ('айтпаса', 'VERB'),
#   ('да', 'ADP'),
#   (',', 'PUNCT'),
#   ('Өрік', 'PROPN'),
#   ('шешесі', 'NOUN'),
#   ('елге', 'NOUN'),
#   ('жаяды', 'VERB'),
#   ('ғой', 'ADP'),
#   ('.', 'PUNCT')],
#  [('Ал', 'SCONJ'),
#   ('бізде', 'PRON'),
#   ('мұндай', 'ADJ'),
#   ('тетіктер', 'NOUN'),
#   ('тиімді', 'ADJ'),
#   ('жұмыс', 'NOUN'),
#   ('істеуде', 'VERB'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('деді', 'VERB'),
#   ('Ресей', 'PROPN'),
#   ('Президенті', 'PROPN'),
#   ('.', 'PUNCT')],
#  [('Танымал', 'ADJ'),
#   ('кісідей', 'ADV'),
#   ('олар', 'PRON'),
#   ('да', 'ADP'),
#   ('Қартқожаға', 'PROPN'),
#   ('басын', 'NOUN'),
#   ('шұлғып', 'VERB'),
#   ('барады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Қалың', 'NOUN'),
#   ('берген', 'VERB'),
#   ('жоқ', 'AUX'),
#   ('па', 'PART'),
#   ('еді', 'AUX'),
#   ('?', 'PUNCT'),
#   ('»', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деп', 'VERB'),
#   (',', 'PUNCT'),
#   ('ойланып', 'VERB'),
#   ('отырып', 'AUX'),
#   ('тағы', 'ADV'),
#   ('сұрады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Қандай', 'PRON'),
#   ('орын', 'NOUN'),
#   ('беруді', 'VERB'),
#   ('ревкомға', 'NOUN'),
#   ('тапсырыпты', 'VERB'),
#   (':', 'PUNCT'),
#   ('ревкомдағы', 'ADJ'),
#   ('Балташ', 'PROPN'),
#   (',', 'PUNCT'),
#   ('кім', 'PRON'),
#   ('біледі', 'VERB'),
#   (',', 'PUNCT'),
#   ('Балташ', 'PROPN'),
#   ('кедейшіл', 'ADJ'),
#   (',', 'PUNCT'),
#   ('бір', 'NUM'),
#   ('беткей', 'ADJ'),
#   ('кісі', 'NOUN'),
#   (',', 'PUNCT'),
#   ('Мұқашты', 'PROPN'),
#   ('Сартауға', 'PROPN'),
#   ('болыс', 'NOUN'),
#   ('қып', 'VERB'),
#   ('жібере', 'VERB'),
#   ('ме', 'PART'),
#   ('?', 'PUNCT')],
#  [('Кешпешіл', 'ADJ'),
#   ('құстар', 'NOUN'),
#   ('деп', 'VERB'),
#   ('көлшік', 'NOUN'),
#   (',', 'PUNCT'),
#   ('шалшық', 'NOUN'),
#   ('суларды', 'NOUN'),
#   ('сағалап', 'VERB'),
#   (',', 'PUNCT'),
#   ('өмірінің', 'NOUN'),
#   ('көбін', 'NOUN'),
#   ('кешпеде', 'NOUN'),
#   ('өткізетін', 'VERB'),
#   ('құстарды', 'NOUN'),
#   ('айтамыз', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Жыл', 'NOUN'),
#   ('сайын', 'ADP'),
#   ('өтетін', 'VERB'),
#   ('Орталық', 'ADJ'),
#   ('Азиядағы', 'ADJ'),
#   ('қауіпсіздік', 'NOUN'),
#   ('жөніндегі', 'ADP'),
#   ('конференцияда', 'NOUN'),
#   ('ҚХР-дың', 'PROPN'),
#   ('Қазақстандағы', 'ADJ'),
#   ('елшісі', 'NOUN'),
#   ('Ханьхуэй', 'PROPN'),
#   ('Чжан', 'PROPN'),
#   ('осылай', 'ADV'),
#   ('деді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Сиырдың', 'NOUN'),
#   ('адамға', 'NOUN'),
#   ('пайдасы', 'NOUN'),
#   ('көп', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Арада', 'NOUN'),
#   ('төрт', 'NUM'),
#   ('-', 'PUNCT'),
#   ('бес', 'NUM'),
#   ('күн', 'NOUN'),
#   ('өтті', 'VERB'),
#   ('ме', 'PART'),
#   (',', 'PUNCT'),
#   ('қалай', 'PRON'),
#   ('.', 'PUNCT')],
#  [('Орталық', 'ADJ'),
#   ('мемлекеттік', 'ADJ'),
#   ('органдардың', 'NOUN'),
#   ('басшылары', 'NOUN'),
#   (',', 'PUNCT'),
#   ('облыстардың', 'NOUN'),
#   ('және', 'CONJ'),
#   ('Астана', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('Алматы', 'PROPN'),
#   ('қалаларының', 'NOUN'),
#   ('әкімдері', 'NOUN'),
#   ('қатысқан', 'VERB'),
#   ('кеңесте', 'NOUN'),
#   ('елдің', 'NOUN'),
#   ('4', 'NUM'),
#   ('айдағы', 'ADJ'),
#   ('әлеуметтік-экономикалық', 'ADJ'),
#   ('даму', 'NOUN'),
#   ('қорытындылары', 'NOUN'),
#   (',', 'PUNCT'),
#   ('негізгі', 'ADJ'),
#   ('мемлекеттік', 'ADJ'),
#   ('бағдарламаларды', 'NOUN'),
#   ('өңірлерде', 'NOUN'),
#   ('жүзеге', 'NOUN'),
#   ('асыру', 'VERB'),
#   ('мәселелері', 'NOUN'),
#   (',', 'PUNCT'),
#   ('Тәуелсіздіктің', 'PROPN'),
#   ('25', 'NUM'),
#   ('жылдығын', 'NOUN'),
#   ('мерекелеуге', 'VERB'),
#   ('дайындық', 'NOUN'),
#   ('барысы', 'NOUN'),
#   ('талқыланды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Сайлау', 'NOUN'),
#   ('жарияланған', 'VERB'),
#   ('(', 'PUNCT'),
#   ('тағайындалған', 'VERB'),
#   (')', 'PUNCT'),
#   ('кезден', 'NOUN'),
#   ('бастап', 'VERB'),
#   (',', 'PUNCT'),
#   ('кандидаттарға', 'NOUN'),
#   (',', 'PUNCT'),
#   ('партиялық', 'ADJ'),
#   ('тізімдерін', 'NOUN'),
#   ('ұсынған', 'VERB'),
#   ('саяси', 'ADJ'),
#   ('партияларға', 'NOUN'),
#   (',', 'PUNCT'),
#   ('сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   ('олардың', 'PRON'),
#   ('атынан', 'NOUN'),
#   ('немесе', 'CONJ'),
#   ('оларды', 'PRON'),
#   ('қолдап', 'VERB'),
#   ('кез', 'ADV'),
#   ('келген', 'VERB'),
#   ('жеке', 'ADJ'),
#   ('және', 'CONJ'),
#   ('заңды', 'ADJ'),
#   ('тұлғаларға', 'NOUN'),
#   (',', 'PUNCT'),
#   ('ойын', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('сауық', 'NOUN'),
#   ('және', 'CONJ'),
#   ('спорттық', 'ADJ'),
#   ('іс', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('шараларын', 'NOUN'),
#   ('ұйымдастыруды', 'VERB'),
#   ('қоспағанда', 'VERB'),
#   (',', 'PUNCT'),
#   ('қайырымдылық', 'NOUN'),
#   ('іс', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('шараларын', 'NOUN'),
#   ('өткізуге', 'VERB'),
#   ('тыйым', 'NOUN'),
#   ('салынады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('“', 'PUNCT'),
#   ('Егер', 'SCONJ'),
#   ('халық', 'NOUN'),
#   ('қолдап', 'VERB'),
#   (',', 'PUNCT'),
#   ('ел', 'NOUN'),
#   ('президенті', 'NOUN'),
#   ('бұрынғыдай', 'ADJ'),
#   ('бес', 'NUM'),
#   ('жылға', 'NOUN'),
#   ('емес', 'VERB'),
#   (',', 'PUNCT'),
#   ('жеті', 'NUM'),
#   ('жыл', 'NOUN'),
#   ('мерзімге', 'NOUN'),
#   ('сайланатын', 'VERB'),
#   ('болса', 'AUX'),
#   (',', 'PUNCT'),
#   ('онда', 'ADV'),
#   ('“', 'PUNCT'),
#   ('бірінші', 'NUM'),
#   ('вице-президент', 'NOUN'),
#   ('”', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('“', 'PUNCT'),
#   ('вице-президент', 'NOUN'),
#   ('”', 'PUNCT'),
#   ('деген', 'VERB'),
#   ('тағы', 'ADJ'),
#   ('екі', 'NUM'),
#   ('лауазым', 'NOUN'),
#   ('енгізіледі', 'VERB'),
#   ('”', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деді', 'VERB'),
#   ('С.', 'PROPN'),
#   ('Наурызов', 'PROPN'),
#   ('.', 'PUNCT')],
#  [('Ұйықтағанды', 'VERB'),
#   ('көтере', 'VERB'),
#   ('алмайтын', 'AUX'),
#   ('әлсіздері', 'ADJ'),
#   ('қырылып', 'VERB'),
#   ('қалады', 'AUX'),
#   ('да', 'ADP'),
#   (',', 'PUNCT'),
#   ('көтере', 'VERB'),
#   ('алатындары', 'AUX'),
#   ('тірі', 'ADJ'),
#   ('қалады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('екеуінің', 'NUM'),
#   ('қатысқанынан', 'VERB'),
#   ('шығатын', 'VERB'),
#   ('дөрекі', 'ADJ'),
#   ('тұқымы', 'NOUN'),
#   ('бар', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Сонымен', 'CONJ'),
#   ('бірге', 'ADP'),
#   ('жүйемен', 'NOUN'),
#   ('берілетін', 'VERB'),
#   ('судың', 'NOUN'),
#   ('бос', 'ADV'),
#   ('кетуі', 'VERB'),
#   ('жыл', 'NOUN'),
#   ('сайын', 'ADP'),
#   ('30', 'NUM'),
#   ('%-дан', 'SYM'),
#   ('астамды', 'NOUN'),
#   ('құрайды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Кезінде', 'NOUN'),
#   ('журналистер', 'NOUN'),
#   ('Ф.', 'PROPN'),
#   ('Кастродан', 'PROPN'),
#   ('“', 'PUNCT'),
#   ('Нені', 'PRON'),
#   ('айрықша', 'ADV'),
#   ('жек', 'ADJ'),
#   ('көресіз', 'VERB'),
#   ('?', 'PUNCT'),
#   ('”', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('сұрағанда', 'VERB'),
#   (',', 'PUNCT'),
#   ('Фидель', 'PROPN'),
#   ('“', 'PUNCT'),
#   ('Ұсақтықты', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Гүленшілерден', 'NOUN'),
#   ('»', 'PUNCT'),
#   ('тазалау', 'VERB'),
#   ('түрікмендерге', 'NOUN'),
#   ('жетті', 'VERB')],
#  [('Республика', 'PROPN'),
#   ('Президентін', 'PROPN'),
#   ('күзету', 'VERB'),
#   ('Республика', 'PROPN'),
#   ('Президентінің', 'PROPN'),
#   ('Күзет', 'PROPN'),
#   ('қызметіне', 'NOUN'),
#   ('жүктеледі', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Оның', 'PRON'),
#   ('құрамына', 'NOUN'),
#   ('мұражай', 'NOUN'),
#   ('қызметкерлері', 'NOUN'),
#   ('ғана', 'ADP'),
#   ('емес', 'VERB'),
#   (',', 'PUNCT'),
#   ('сарапшылар', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('өнертанушылар', 'NOUN'),
#   (',', 'PUNCT'),
#   ('тарихшылар', 'NOUN'),
#   (',', 'PUNCT'),
#   ('археологтар', 'NOUN'),
#   (',', 'PUNCT'),
#   ('нумизматтар', 'NOUN'),
#   ('және', 'CONJ'),
#   ('т.б.', 'NOUN'),
#   ('кіреді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Істі', 'NOUN'),
#   ('Ақтөбе', 'PROPN'),
#   ('облыстық', 'ADJ'),
#   ('мамандандырылған', 'VERB'),
#   ('ауданаралық', 'ADJ'),
#   ('сотта', 'NOUN'),
#   ('қарайды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Кейбіреулері', 'PRON'),
#   ('құлдарын', 'NOUN'),
#   ('жарыққа', 'NOUN'),
#   ('шығармай', 'VERB'),
#   (',', 'PUNCT'),
#   ('жер', 'NOUN'),
#   ('астындағы', 'ADJ'),
#   ('жұмысқа', 'NOUN'),
#   ('салады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('«', 'PUNCT'),
#   ('Атамекен', 'PROPN'),
#   ('»', 'PUNCT'),
#   ('Ұлттық', 'ADJ'),
#   ('кәсіпкерлер', 'NOUN'),
#   ('палатасы', 'NOUN'),
#   ('жекешелендіру', 'NOUN'),
#   ('нысандарын', 'NOUN'),
#   ('құнын', 'NOUN'),
#   ('бөліп', 'VERB'),
#   ('төлеумен', 'VERB'),
#   ('бизнеске', 'NOUN'),
#   ('беруді', 'VERB'),
#   ('ұсынды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Өздеріңізге', 'PRON'),
#   ('мәлім', 'ADJ'),
#   (',', 'PUNCT'),
#   ('біз', 'PRON'),
#   ('Иран', 'PROPN'),
#   ('мәселесіне', 'NOUN'),
#   ('атсалыстық', 'VERB'),
#   (',', 'PUNCT'),
#   ('Сирияға', 'PROPN'),
#   ('да', 'ADP'),
#   ('көмектесуге', 'VERB'),
#   ('ниеттіміз', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Бұған', 'PRON'),
#   ('дейін', 'ADP'),
#   ('“', 'PUNCT'),
#   ('Азаттықтың', 'PROPN'),
#   ('”', 'PUNCT'),
#   ('өзбек', 'NOUN'),
#   ('қызметі', 'NOUN'),
#   ('құпия', 'ADJ'),
#   ('дереккөзге', 'NOUN'),
#   ('сүйеніп', 'VERB'),
#   (',', 'PUNCT'),
#   ('Жалиловтың', 'PROPN'),
#   ('“', 'PUNCT'),
#   ('Өзбекстан', 'PROPN'),
#   ('президенті', 'NOUN'),
#   ('Ислам', 'PROPN'),
#   ('Каримовтың', 'PROPN'),
#   ('ісіне', 'NOUN'),
#   ('араласқаны', 'VERB'),
#   ('үшін', 'ADP'),
#   ('тұтқынға', 'NOUN'),
#   ('алынды', 'VERB'),
#   ('”', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('хабарлаған', 'VERB'),
#   ('болатын', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Жануардың', 'NOUN'),
#   ('құрсағы', 'NOUN'),
#   ('құр', 'ADV'),
#   ('жатқан', 'VERB'),
#   ('емес', 'AUX'),
#   ('еді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Халықаралық', 'ADJ'),
#   ('байқаушылар', 'NOUN'),
#   ('өз', 'PRON'),
#   ('кезегінде', 'NOUN'),
#   ('сайлау', 'NOUN'),
#   ('үдерісін', 'NOUN'),
#   ('оң', 'ADV'),
#   ('бағалап', 'VERB'),
#   (',', 'PUNCT'),
#   ('сайлау', 'NOUN'),
#   ('қорытындысы', 'NOUN'),
#   ('екі', 'NUM'),
#   ('құрлықтың', 'NOUN'),
#   ('арасындағы', 'ADJ'),
#   ('табиғи', 'ADJ'),
#   ('көпір', 'NOUN'),
#   ('болып', 'VERB'),
#   ('отырған', 'AUX'),
#   ('Қазақстандағы', 'ADJ'),
#   ('демократияның', 'NOUN'),
#   ('жеңісін', 'NOUN'),
#   ('ғана', 'ADP'),
#   ('емес', 'VERB'),
#   (',', 'PUNCT'),
#   ('Азия', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('Еуропаның', 'PROPN'),
#   ('барша', 'PRON'),
#   ('демократиялық', 'ADJ'),
#   ('қоғамдарының', 'NOUN'),
#   ('болашағын', 'NOUN'),
#   ('да', 'ADP'),
#   ('паш', 'ADJ'),
#   ('еткенін', 'VERB'),
#   ('атап', 'VERB'),
#   ('өтті', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Махмұттың', 'PROPN'),
#   ('көңілі', 'NOUN'),
#   ('бұзылайын', 'VERB'),
#   ('деді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Мемлекет', 'PROPN'),
#   ('басшысы', 'NOUN'),
#   ('қазақ', 'NOUN'),
#   ('-', 'PUNCT'),
#   ('қырғыз', 'NOUN'),
#   ('қарым-қатынасы', 'NOUN'),
#   ('әрдайым', 'ADV'),
#   ('жоғары', 'ADJ'),
#   ('деңгейде', 'NOUN'),
#   ('екенін', 'VERB'),
#   (',', 'PUNCT'),
#   ('Қырғызстанның', 'PROPN'),
#   ('ЕАЭО-ға', 'PROPN'),
#   ('кіруі', 'VERB'),
#   ('қазірдің', 'ADV'),
#   ('өзінде', 'PRON'),
#   ('1', 'NUM'),
#   ('миллиард', 'NUM'),
#   ('доллардан', 'NOUN'),
#   ('асатын', 'VERB'),
#   ('тауар', 'NOUN'),
#   ('айналымын', 'NOUN'),
#   ('одан', 'PRON'),
#   ('әрі', 'ADV'),
#   ('жандандыра', 'VERB'),
#   ('түсуге', 'AUX'),
#   ('жағдай', 'NOUN'),
#   ('туғызатынын', 'VERB'),
#   ('айтты', 'VERB'),
#   ('.', 'PUNCT')],
# ...
#   ('қабылдады', 'VERB')],
#  [('Жолаушылар', 'NOUN'),
#   ('айтады', 'VERB'),
#   (':', 'PUNCT'),
#   ('ең', 'ADV'),
#   ('жабайы', 'ADJ'),
#   ('елде', 'NOUN'),
#   ('де', 'ADP'),
#   ('бөренелерден', 'NOUN'),
#   ('сал', 'NOUN'),
#   ('жасап', 'VERB'),
#   (',', 'PUNCT'),
#   ('өзен', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('көлдерден', 'NOUN'),
#   ('өтеді', 'VERB'),
#   ('деп', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('мәселе', 'NOUN'),
#   ('таяу', 'ADJ'),
#   ('уақытта', 'NOUN'),
#   ('шешілуі', 'VERB'),
#   ('мүмкін', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Елдеріміздің', 'NOUN'),
#   ('тарихи', 'ADJ'),
#   ('тамыры', 'NOUN'),
#   ('ортақ', 'ADJ'),
#   ('және', 'CONJ'),
#   ('даму', 'NOUN'),
#   ('жолдары', 'NOUN'),
#   ('ұқсас', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Ел', 'NOUN'),
#   ('ішінде', 'NOUN'),
#   ('не', 'PRON'),
#   ('болып', 'VERB'),
#   ('жатқанын', 'AUX'),
#   ('жазады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Жер', 'NOUN'),
#   ('кодексінің', 'NOUN'),
#   ('қоғамдық', 'ADJ'),
#   ('резонанс', 'NOUN'),
#   ('тудырған', 'VERB'),
#   ('бірқатар', 'PRON'),
#   ('нормаларын', 'NOUN'),
#   (',', 'PUNCT'),
#   ('нақты', 'ADV'),
#   ('айтқанда', 'VERB'),
#   (',', 'PUNCT'),
#   ('былтыр', 'ADV'),
#   ('енгізілген', 'VERB'),
#   ('4', 'NUM'),
#   ('норманы', 'NOUN'),
#   ('күшіне', 'NOUN'),
#   ('енгізуге', 'VERB'),
#   ('ендігі', 'ADJ'),
#   ('жылға', 'NOUN'),
#   ('дейін', 'ADP'),
#   ('мораторий', 'NOUN'),
#   ('жариялаймын', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Екі', 'NUM'), ('министр', 'NOUN'), ('орын', 'NOUN'), ('босатты', 'VERB')],
#  [('Сайлау', 'NOUN'),
#   ('комиссияларының', 'NOUN'),
#   ('жаңа', 'ADJ'),
#   ('құрамын', 'NOUN'),
#   ('құру', 'VERB'),
#   ('сайлау', 'NOUN'),
#   ('комиссияларының', 'NOUN'),
#   ('өкілеттік', 'NOUN'),
#   ('мерзімі', 'NOUN'),
#   ('аяқталардан', 'VERB'),
#   ('кемінде', 'NOUN'),
#   ('екі', 'NUM'),
#   ('ай', 'NOUN'),
#   ('бұрын', 'ADV'),
#   ('басталады', 'VERB'),
#   ('және', 'CONJ'),
#   ('өкілеттік', 'NOUN'),
#   ('мерзімінің', 'NOUN'),
#   ('бітуіне', 'VERB'),
#   ('кемінде', 'NOUN'),
#   ('үш', 'NUM'),
#   ('күн', 'NOUN'),
#   ('қалғанда', 'VERB'),
#   ('аяқталады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Олардың', 'PRON'),
#   ('пайымының', 'NOUN'),
#   ('мәні', 'NOUN'),
#   ('мынадай', 'ADJ'),
#   (':', 'PUNCT'),
#   ('Қазақстанда', 'PROPN'),
#   ('қалай', 'PRON'),
#   ('болса', 'VERB'),
#   (',', 'PUNCT'),
#   ('Ресейде', 'PROPN'),
#   ('де', 'ADP'),
#   ('солай', 'ADV'),
#   ('деп', 'VERB'),
#   ('ойлайды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Соның', 'PRON'),
#   ('арғымағына', 'NOUN'),
#   ('мініп', 'VERB'),
#   ('кататься', 'NOUN'),
#   ('қыла', 'VERB'),
#   ('беруші', 'AUX'),
#   ('еді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Қарағандылық', 'ADJ'),
#   ('адвокат', 'NOUN'),
#   ('Нұрхан', 'PROPN'),
#   ('Жұмабеков', 'PROPN'),
#   ('Алматының', 'PROPN'),
#   ('Бостандық', 'PROPN'),
#   ('аудандық', 'ADJ'),
#   ('сотына', 'NOUN'),
#   ('“', 'PUNCT'),
#   ('Еуразия', 'PROPN'),
#   ('”', 'PUNCT'),
#   ('“', 'PUNCT'),
#   ('бірінші', 'NUM'),
#   ('арнасына', 'NOUN'),
#   ('”', 'PUNCT'),
#   ('тиесілі', 'ADJ'),
#   ('“', 'PUNCT'),
#   ('Еуразия+ОРТ', 'PROPN'),
#   ('”', 'PUNCT'),
#   ('компаниясының', 'NOUN'),
#   ('үстінен', 'NOUN'),
#   ('шағым', 'NOUN'),
#   ('түсірді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Біздің', 'PRON'),
#   ('елдеріміздің', 'NOUN'),
#   ('екіжақты', 'ADJ'),
#   ('қарым-қатынастарын', 'NOUN'),
#   ('дамытуға', 'VERB'),
#   ('мүдделілік', 'NOUN'),
#   ('танытқаныңыз', 'VERB'),
#   ('үшін', 'ADP'),
#   ('алғысымды', 'NOUN'),
#   ('қабыл', 'NOUN'),
#   ('алыңыз', 'VERB'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('делінген', 'VERB'),
#   ('жеделхатта', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Кездесу', 'NOUN'),
#   ('барысында', 'ADP'),
#   ('ақпараттық', 'ADJ'),
#   ('қауіпсіздік', 'NOUN'),
#   (',', 'PUNCT'),
#   ('ішкі', 'ADJ'),
#   ('және', 'CONJ'),
#   ('сыртқы', 'ADJ'),
#   ('ақпараттық', 'ADJ'),
#   ('саясат', 'NOUN'),
#   ('мәселелері', 'NOUN'),
#   ('сөз', 'NOUN'),
#   ('болған', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Сол', 'PRON'),
#   ('кезеңдегі', 'ADJ'),
#   ('халқымыздың', 'NOUN'),
#   ('20', 'NUM'),
#   ('пайызға', 'NOUN'),
#   ('жуығы', 'NOUN'),
#   ('–', 'PUNCT'),
#   ('бір', 'NUM'),
#   ('жарым', 'ADJ'),
#   ('миллион', 'NUM'),
#   ('адам', 'NOUN'),
#   ('майданға', 'NOUN'),
#   ('аттанды', 'VERB'),
#   (',', 'PUNCT'),
#   ('соның', 'PRON'),
#   ('жартысы', 'ADJ'),
#   ('ғана', 'ADP'),
#   ('оралды', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Будданы', 'PROPN'),
#   ('тұмсығынан', 'NOUN'),
#   ('теуіп', 'VERB'),
#   ('.', 'PUNCT'),
#   ('.', 'PUNCT'),
#   ('.', 'PUNCT')],
#  [('Көрмеген', 'VERB'),
#   ('кісі', 'NOUN'),
#   ('дала', 'NOUN'),
#   ('шөбінің', 'NOUN'),
#   ('әсемдігін', 'NOUN'),
#   ('біле', 'VERB'),
#   ('алмайды', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Құрал', 'NOUN'), ('өзгерді', 'VERB'), ('.', 'PUNCT')],
#  [('Фермерлер', 'NOUN'),
#   ('әлгі', 'ADJ'),
#   ('шенеуніктерге', 'NOUN'),
#   ('олардың', 'PRON'),
#   ('Қырғызстан', 'PROPN'),
#   ('Еуразиялық', 'ADJ'),
#   ('экономикалық', 'ADJ'),
#   ('одаққа', 'NOUN'),
#   ('мүше', 'NOUN'),
#   ('боп', 'VERB'),
#   ('кіргенде', 'VERB'),
#   ('Ресей', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('Қазақстан', 'PROPN'),
#   ('нарығының', 'NOUN'),
#   ('есігі', 'NOUN'),
#   ('айқара', 'ADV'),
#   ('ашылатыны', 'VERB'),
#   ('туралы', 'ADP'),
#   ('уәделерін', 'NOUN'),
#   ('естеріне', 'NOUN'),
#   ('салып', 'VERB'),
#   (',', 'PUNCT'),
#   ('уәж', 'NOUN'),
#   ('де', 'ADP'),
#   ('айтып', 'VERB'),
#   ('көріпті', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Қай', 'PRON'),
#   ('тұрғыдан', 'NOUN'),
#   ('алып', 'VERB'),
#   ('қарасаңыз', 'VERB'),
#   ('да', 'ADP'),
#   ('.', 'PUNCT')],
#  [('Ал', 'SCONJ'),
#   ('Ресей', 'PROPN'),
#   ('бас', 'ADJ'),
#   ('прокуратурасы', 'NOUN'),
#   ('13', 'NUM'),
#   ('желтоқсан', 'NOUN'),
#   ('күні', 'NOUN'),
#   ('Франция', 'PROPN'),
#   ('шешімін', 'NOUN'),
#   ('“', 'PUNCT'),
#   ('саясиландырылған', 'VERB'),
#   ('шешім', 'NOUN'),
#   ('”', 'PUNCT'),
#   ('деп', 'VERB'),
#   ('санайтынын', 'VERB'),
#   ('жеткізген', 'VERB'),
#   ('еді', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Үндістанмен', 'PROPN'),
#   ('стратегиялық', 'ADJ'),
#   ('серіктестікті', 'NOUN'),
#   ('дамыту', 'VERB'),
#   ('–', 'PUNCT'),
#   ('біздің', 'PRON'),
#   ('сыртқы', 'ADJ'),
#   ('саясатымыздың', 'NOUN'),
#   ('Азия', 'PROPN'),
#   ('векторындағы', 'ADJ'),
#   ('басым', 'ADJ'),
#   ('бағытының', 'NOUN'),
#   ('бірі', 'PRON'),
#   (',', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деді', 'VERB'),
#   ('Мемлекет', 'PROPN'),
#   ('басшысы', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Мылтықбайдың', 'PROPN'),
#   ('терісін', 'NOUN'),
#   ('алдың', 'VERB'),
#   ('ба', 'PART'),
#   ('?', 'PUNCT')],
#  [('Бұл', 'PRON'),
#   ('мәселе', 'NOUN'),
#   ('таяу', 'ADJ'),
#   ('уақытта', 'NOUN'),
#   ('шешілуі', 'VERB'),
#   ('мүмкін', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Кеше', 'ADV'),
#   ('түсте', 'NOUN'),
#   ('«', 'PUNCT'),
#   ('Астана', 'PROPN'),
#   ('-', 'PUNCT'),
#   ('Сарыағаш', 'PROPN'),
#   ('»', 'PUNCT'),
#   ('бағытындағы', 'ADJ'),
#   ('№', 'SYM'),
#   ('86', 'NUM'),
#   ('жолаушылар', 'NOUN'),
#   ('пойызының', 'NOUN'),
#   ('вагонында', 'NOUN'),
#   ('өрт', 'NOUN'),
#   ('шықты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Башқұрт', 'NOUN'),
#   ('тұрмысын', 'NOUN'),
#   ('сұрады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Тау', 'NOUN'),
#   ('жаңғырықтырған', 'VERB'),
#   ('шақ-шұқ', 'NOUN'),
#   ('темір', 'NOUN'),
#   ('дауысы', 'NOUN'),
#   ('шығады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ә', 'NOUN'),
#   ('дегенде', 'VERB'),
#   ('бойы', 'NOUN'),
#   ('әнтек', 'ADV'),
#   ('сейілген', 'VERB'),
#   ('тәрізденді', 'AUX'),
#   (',', 'PUNCT'),
#   ('аздан', 'ADJ'),
#   ('соң', 'ADP'),
#   ('шекесіне', 'NOUN'),
#   ('қыл', 'ADJ'),
#   ('бұрау', 'NOUN'),
#   ('салған', 'VERB'),
#   ('адамдай', 'ADJ'),
#   ('басы', 'NOUN'),
#   ('тарыла', 'VERB'),
#   ('бастады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Сондықтан', 'SCONJ'),
#   ('баланы', 'NOUN'),
#   ('қауіпті', 'ADJ'),
#   ('интернет', 'NOUN'),
#   ('желілерінен', 'NOUN'),
#   ('сақтандыру', 'VERB'),
#   ('әрбір', 'PRON'),
#   ('ата-ананың', 'NOUN'),
#   ('міндеті', 'NOUN'),
#   ('екенін', 'VERB'),
#   ('ұмытпайық', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Ардагерден', 'NOUN'), ('кешірім', 'NOUN'), ('сұрады', 'VERB')],
#  [('Кірпігін', 'NOUN'),
#   ('әрең', 'ADV'),
#   ('қағып', 'VERB'),
#   (',', 'PUNCT'),
#   ('аз', 'ADJ'),
#   ('уақыт', 'NOUN'),
#   ('жатқан', 'VERB'),
#   ('соң', 'ADP'),
#   (',', 'PUNCT'),
#   ('ақтық', 'ADJ'),
#   ('күшін', 'NOUN'),
#   ('жинап', 'VERB'),
#   (',', 'PUNCT'),
#   ('қатын-балаларын', 'NOUN'),
#   ('шақырып', 'VERB'),
#   ('алып', 'AUX'),
#   (',', 'PUNCT'),
#   ('қол', 'NOUN'),
#   ('ұстасып', 'VERB'),
#   (',', 'PUNCT'),
#   ('қоштасты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Егер', 'SCONJ'),
#   ('қойылған', 'VERB'),
#   ('қолдардың', 'NOUN'),
#   ('растығын', 'NOUN'),
#   ('тексеру', 'VERB'),
#   ('нәтижесінде', 'NOUN'),
#   ('жиналған', 'VERB'),
#   ('қолдардың', 'NOUN'),
#   ('бір', 'NUM'),
#   ('процентінен', 'NOUN'),
#   ('артығы', 'NOUN'),
#   ('рас', 'ADJ'),
#   ('болмай', 'VERB'),
#   ('шыққан', 'AUX'),
#   ('жағдайда', 'NOUN'),
#   (',', 'PUNCT'),
#   ('Сенат', 'PROPN'),
#   ('депутаттығына', 'NOUN'),
#   ('кандидатты', 'NOUN'),
#   ('тіркеуден', 'VERB'),
#   ('бас', 'NOUN'),
#   ('тартылады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Сонымен', 'CONJ'),
#   ('қатар', 'ADP'),
#   ('Аслан', 'PROPN'),
#   ('Сәрінжіпов', 'PROPN'),
#   ('министрліктің', 'NOUN'),
#   ('алдында', 'NOUN'),
#   ('кәсіби', 'ADJ'),
#   ('стандарттарды', 'NOUN'),
#   ('әзірлеу', 'VERB'),
#   ('бойынша', 'ADP'),
#   ('үлкен', 'ADJ'),
#   ('міндеттер', 'NOUN'),
#   ('тұрғанын', 'VERB'),
#   ('қосты', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Орыста', 'NOUN'),
#   ('мұндай', 'ADJ'),
#   ('нәрсе', 'NOUN'),
#   ('жоқ', 'ADJ'),
#   ('еді', 'VERB'),
#   ('ғой', 'ADP'),
#   ('деп', 'VERB'),
#   ('ойлауы', 'VERB'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   ('мұң', 'ADJ'),
#   ('екен', 'VERB'),
#   ('—', 'PUNCT'),
#   ('шошақай', 'NOUN'),
#   ('жуандады', 'VERB'),
#   (':', 'PUNCT'),
#   ('бас', 'NOUN'),
#   ('болды', 'VERB'),
#   (',', 'PUNCT'),
#   ('кәдімгі', 'ADJ'),
#   ('дуананың', 'NOUN'),
#   ('басы', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Спортшыларымыз', 'NOUN'),
#   ('допингке', 'NOUN'),
#   ('тестілеуден', 'VERB'),
#   ('өткенде', 'VERB'),
#   ('біз', 'PRON'),
#   ('үшін', 'ADP'),
#   ('күтпеген', 'VERB'),
#   ('тосын', 'ADJ'),
#   ('жайлар', 'NOUN'),
#   ('болмауы', 'VERB'),
#   ('және', 'CONJ'),
#   ('олар', 'PRON'),
#   ('сенімді', 'ADJ'),
#   ('болуы', 'VERB'),
#   ('үшін', 'ADP'),
#   ('жақсы', 'ADJ'),
#   ('зертхана', 'NOUN'),
#   ('сатып', 'VERB'),
#   ('алуға', 'AUX'),
#   ('мүмкін', 'AUX'),
#   (',', 'PUNCT'),
#   ('жеке', 'ADJ'),
#   ('қаражат', 'NOUN'),
#   ('есебінен', 'NOUN'),
#   (',', 'PUNCT'),
#   ('мүмкіндіктер', 'NOUN'),
#   ('іздеу', 'VERB'),
#   ('керек', 'AUX'),
#   ('»', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('-', 'PUNCT'),
#   ('деді', 'VERB'),
#   ('К.', 'PROPN'),
#   ('Мәсімов', 'PROPN'),
#   ('мәдениет', 'NOUN'),
#   ('және', 'CONJ'),
#   ('спорт', 'NOUN'),
#   ('министрі', 'NOUN'),
#   ('Арыстанбек', 'PROPN'),
#   ('Мұхамедиұлына', 'PROPN'),
#   ('қарата', 'VERB'),
#   ('айтқан', 'VERB'),
#   ('сөзінде', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Сондай', 'CONJ'),
#   ('-', 'PUNCT'),
#   ('ақ', 'ADP'),
#   ('премьер-министрдің', 'NOUN'),
#   ('ойынша', 'ADV'),
#   (',', 'PUNCT'),
#   ('мигранттарға', 'NOUN'),
#   ('алғашқы', 'ADJ'),
#   ('төрт', 'NUM'),
#   ('жылда', 'NOUN'),
#   ('әлеуметтік', 'ADJ'),
#   ('көмек', 'NOUN'),
#   ('мүлде', 'ADV'),
#   ('төленбеуі', 'VERB'),
#   ('тиіс', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Арамызда', 'NOUN'),
#   ('аман-сау', 'ADV'),
#   ('жүріп', 'VERB'),
#   (',', 'PUNCT'),
#   ('жастарды', 'NOUN'),
#   ('патриоттық', 'NOUN'),
#   ('пен', 'CONJ'),
#   ('Отанға', 'PROPN'),
#   ('адалдық', 'NOUN'),
#   ('рухында', 'NOUN'),
#   ('тәрбиелей', 'VERB'),
#   ('беріңіздер', 'AUX'),
#   ('!', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деді', 'VERB'),
#   ('Нұрсұлтан', 'PROPN'),
#   ('Назарбаев', 'PROPN'),
#   ('.', 'PUNCT')],
#  [('Бүгінде', 'ADV'),
#   ('атом', 'NOUN'),
#   ('электр', 'NOUN'),
#   ('стансасын', 'NOUN'),
#   ('салуға', 'VERB'),
#   ('ниетті', 'ADJ'),
#   ('немесе', 'CONJ'),
#   ('сондай', 'ADJ'),
#   ('жолды', 'NOUN'),
#   ('қарастырып', 'VERB'),
#   ('отырған', 'AUX'),
#   ('елдер', 'NOUN'),
#   ('уран', 'NOUN'),
#   ('нарығындағы', 'ADJ'),
#   ('кез', 'ADJ'),
#   ('келген', 'ADJ'),
#   ('ауытқуларға', 'NOUN'),
#   ('қарамастан', 'VERB'),
#   (',', 'PUNCT'),
#   ('аз', 'ADV'),
#   ('байытылған', 'VERB'),
#   ('уран', 'NOUN'),
#   ('сатып', 'VERB'),
#   ('алу', 'AUX'),
#   ('мүмкіндігі', 'NOUN'),
#   ('бар', 'ADJ'),
#   ('екеніне', 'VERB'),
#   ('сенімді', 'ADJ'),
#   ('бола', 'VERB'),
#   ('алады', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Ауыз', 'NOUN'),
#   ('әдебиеті', 'NOUN'),
#   (',', 'PUNCT'),
#   ('музыкасы', 'NOUN'),
#   ('бай', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Қонақтар', 'NOUN'),
#   ('керенау', 'ADV'),
#   ('қозғалып', 'VERB'),
#   (',', 'PUNCT'),
#   ('ауыз', 'NOUN'),
#   ('үйге', 'NOUN'),
#   ('қарай', 'ADP'),
#   ('аяңдасты', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Бұған', 'PRON'),
#   ('дейін', 'ADP'),
#   ('шетелдік', 'ADJ'),
#   ('валюталардың', 'NOUN'),
#   ('заңсыз', 'ADJ'),
#   ('саудасымен', 'NOUN'),
#   ('айналысатындарды', 'VERB'),
#   ('қатаң', 'ADV'),
#   ('жазалау', 'VERB'),
#   ('туралы', 'ADP'),
#   ('ұсынысты', 'NOUN'),
#   ('Тәжікстан', 'PROPN'),
#   ('Ұлттық', 'ADJ'),
#   ('банкі', 'NOUN'),
#   ('жасаған', 'VERB'),
#   ('болатын', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Әр', 'PRON'),
#   ('жұмысты', 'NOUN'),
#   ('маусымды', 'ADJ'),
#   ('кезінде', 'NOUN'),
#   ('істеу', 'VERB'),
#   ('керек', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Күш', 'NOUN'),
#   ('салғаны', 'VERB'),
#   ('қолындағы', 'ADJ'),
#   ('қара-құрасы', 'NOUN'),
#   (',', 'PUNCT'),
#   ('қинағаны', 'VERB'),
#   ('қолынан', 'NOUN'),
#   ('келгені', 'VERB'),
#   ('–', 'PUNCT'),
#   ('жаны', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Оның', 'PRON'),
#   ('орнықты', 'ADV'),
#   ('дамуы', 'VERB'),
#   ('осыған', 'PRON'),
#   ('негізделеді', 'VERB'),
#   (',', 'PUNCT'),
#   ('–', 'PUNCT'),
#   ('деді', 'VERB'),
#   ('Мемлекет', 'PROPN'),
#   ('басшысы', 'NOUN'),
#   ('.', 'PUNCT')],
#  [('Республика', 'PROPN'),
#   ('Парламенті', 'PROPN'),
#   ('Сенатының', 'PROPN'),
#   ('депутаттарын', 'NOUN'),
#   ('сайлау', 'VERB'),
#   ('жанама', 'ADJ'),
#   ('сайлау', 'NOUN'),
#   ('құқығы', 'NOUN'),
#   ('негізінде', 'NOUN'),
#   ('жасырын', 'ADJ'),
#   ('дауыс', 'NOUN'),
#   ('беру', 'VERB'),
#   ('жағдайында', 'NOUN'),
#   ('өткізіледі', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Қаза', 'NOUN'),
#   ('тапқан', 'VERB'),
#   ('әскери', 'ADJ'),
#   ('қызметкерлер', 'NOUN'),
#   ('отан', 'NOUN'),
#   ('алдындағы', 'ADJ'),
#   ('антына', 'NOUN'),
#   ('адал', 'ADJ'),
#   ('болып', 'VERB'),
#   (',', 'PUNCT'),
#   ('ел', 'NOUN'),
#   ('қауіпсіздігі', 'NOUN'),
#   ('жолында', 'NOUN'),
#   ('өшпес', 'ADJ'),
#   ('ерлік', 'NOUN'),
#   ('көрсетті', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Елдің', 'NOUN'),
#   ('құрығаны', 'VERB'),
#   ('ғой', 'ADP'),
#   ('деп', 'VERB'),
#   ('ойлады', 'VERB'),
#   ('.', 'PUNCT')],
#  [('К.', 'PROPN'),
#   ('Мәсімов', 'PROPN'),
#   ('құрбан', 'NOUN'),
#   ('болғандардың', 'VERB'),
#   ('туған-туыстарына', 'NOUN'),
#   ('жеке', 'ADJ'),
#   ('өзінің', 'PRON'),
#   ('және', 'CONJ'),
#   ('барлық', 'PRON'),
#   ('қазақстандықтардың', 'NOUN'),
#   ('атынан', 'NOUN'),
#   ('қайғырып', 'VERB'),
#   ('көңіл', 'NOUN'),
#   ('айтып', 'VERB'),
#   (',', 'PUNCT'),
#   ('Қазақстанда', 'PROPN'),
#   ('бейбіт', 'ADJ'),
#   ('азаматтардың', 'NOUN'),
#   ('қауіпсіздігін', 'NOUN'),
#   ('қорғау', 'VERB'),
#   ('бүгінгі', 'ADJ'),
#   ('таңда', 'NOUN'),
#   ('басымдықты', 'ADJ'),
#   ('міндеттердің', 'NOUN'),
#   ('бірі', 'PRON'),
#   ('болып', 'VERB'),
#   ('отырғанын', 'AUX'),
#   ('атап', 'VERB'),
#   ('өтті', 'AUX'),
#   ('.', 'PUNCT')],
#  [('Шабуыл', 'NOUN'),
#   ('кезінде', 'NOUN'),
#   ('еліміздің', 'NOUN'),
#   ('жазықсыз', 'ADJ'),
#   ('азаматтары', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('құқық', 'NOUN'),
#   ('қорғау', 'VERB'),
#   ('органдарының', 'NOUN'),
#   ('қызметкерлері', 'NOUN'),
#   ('қаза', 'NOUN'),
#   ('тапты', 'VERB'),
#   (',', 'PUNCT'),
#   ('зардап', 'NOUN'),
#   ('шеккендер', 'VERB'),
#   ('бар', 'ADJ'),
#   ('.', 'PUNCT')],
#  [('Елбасы', 'PROPN'),
#   ('Ақтөбе', 'PROPN'),
#   ('рельсті', 'ADJ'),
#   ('арқалық', 'NOUN'),
#   ('зауытында', 'NOUN'),
#   ('болды', 'VERB')],
#  [('Дүйсенбі', 'NOUN'),
#   ('күні', 'NOUN'),
#   ('Астанада', 'PROPN'),
#   ('«', 'PUNCT'),
#   ('Орал-Дизайн-Стройсервис', 'PROPN'),
#   ('»', 'PUNCT'),
#   ('компаниясының', 'NOUN'),
#   ('үлескерлері', 'NOUN'),
#   ('Жоғарғы', 'ADJ'),
#   ('сот', 'NOUN'),
#   ('алдында', 'NOUN'),
#   ('наразылық', 'NOUN'),
#   ('акциясын', 'NOUN'),
#   ('өткізді', 'VERB'),
#   ('.', 'PUNCT')],
#  [('Жыл', 'NOUN'),
#   ('сайын', 'ADP'),
#   ('дәстүрлі', 'ADJ'),
#   ('түрде', 'NOUN'),
#   ('ұйымдастырылып', 'VERB'),
#   ('отыратын', 'AUX'),
#   ('байқауға', 'NOUN'),
#   ('еліміздің', 'NOUN'),
#   ('14', 'NUM'),
#   ('облысы', 'NOUN'),
#   ('мен', 'CONJ'),
#   ('Астана', 'PROPN'),
#   ('мен', 'CONJ'),
#   ('Алматы', 'PROPN'),
#   ('қалаларынан', 'NOUN'),
#   ('140', 'NUM'),
#   ('үміткер', 'NOUN'),
#   ('қатысқан', 'VERB'),
#   ('.', 'PUNCT')],
#  ...]

# %%
sentence = ["Қазақ", "халқының", "мәдени", "мұрасы"]

# %% [markdown]
# ## Unigram Tagger

# %%
unigram_tagger = UnigramTagger(train_data)
print("Unigram Tagger Accuracy:", unigram_tagger.evaluate(test_data))
# Out:
# Unigram Tagger Accuracy: 0.9416345259822997
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41196\35353207.py:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print("Unigram Tagger Accuracy:", unigram_tagger.evaluate(test_data))

# %%
print(unigram_tagger.tag(sentence))
# Out:
# [('Қазақ', 'NOUN'), ('халқының', 'NOUN'), ('мәдени', 'ADJ'), ('мұрасы', 'NOUN')]

# %% [markdown]
# ## Bigram Tagger (With Backoff)

# %%
bigram_tagger = BigramTagger(train_data, backoff=unigram_tagger)
print("Bigram Tagger Accuracy:", bigram_tagger.evaluate(test_data))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41196\2085187722.py:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print("Bigram Tagger Accuracy:", bigram_tagger.evaluate(test_data))
# Bigram Tagger Accuracy: 0.95894744998106

# %%
print(bigram_tagger.tag(sentence))
# Out:
# [('Қазақ', 'NOUN'), ('халқының', 'NOUN'), ('мәдени', 'ADJ'), ('мұрасы', 'NOUN')]

# %% [markdown]
# ## Trigram Tagger (Best for Context)

# %%
trigram_tagger = TrigramTagger(train_data, backoff=bigram_tagger)
print("Trigram Tagger Accuracy:", trigram_tagger.evaluate(test_data))
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_41196\2865003306.py:2: DeprecationWarning:
#   Function evaluate() has been deprecated.  Use accuracy(gold)
#   instead.
#   print("Trigram Tagger Accuracy:", trigram_tagger.evaluate(test_data))
# Trigram Tagger Accuracy: 0.9634284927166914

# %%
print(trigram_tagger.tag(sentence))
# Out:
# [('Қазақ', 'NOUN'), ('халқының', 'NOUN'), ('мәдени', 'ADJ'), ('мұрасы', 'NOUN')]

# %% [markdown]
# ## Results

# %% [markdown]
# |Model|Test accuracy|
# |-----|-------------|
# |DTC|0.89605|
# |UnigramTagger|0.9416|
# |BigramTagger|0.9589|
# |TrigramTagger|0.9634|
